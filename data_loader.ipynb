# %%
# !pip install neo4j
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting neo4j
#   Downloading neo4j-5.7.0.tar.gz (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.3/176.3 KB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from neo4j) (2022.7.1)
# Building wheels for collected packages: neo4j
#   Building wheel for neo4j (pyproject.toml) ... done
#   Created wheel for neo4j: filename=neo4j-5.7.0-py3-none-any.whl size=244275 sha256=37171eb0a6367d36de3aa3b4041d8fa2054b591e2eabea95c7d3a9eae73bfacb
#   Stored in directory: /root/.cache/pip/wheels/6d/be/1e/749b84bba4b7429145ea09ccb46114fab4748625eb319f286a
# Successfully built neo4j
# Installing collected packages: neo4j
# Successfully installed neo4j-5.7.0

# %%
import pandas as pd
from neo4j import GraphDatabase

# %%
uri = "neo4j+s://76838788.databases.neo4j.io"
user = "neo4j"
password = "urfpim_kxVWH5LgUxt0M1NcEVRhgyPTd9W5ZXjoRQMQ"
driver = GraphDatabase.driver(uri, auth=(user, password))

# %%
KB = pd.read_csv('./KB.csv', delimiter=';')
nombres = pd.read_csv('./nombres.csv', delimiter=';')

# %%
KB = KB.rename(columns={"Descripción Problema - Producción": "descripcion_problema_produccion", 
                   "Localización": "localizacion", 
                   "Fecha Generación": "fecha_generacion",
                   "Inicio Intervención": "inicio_intervencion",
                   "Equipo": "equipo",
                   "Fin Intervención": "fin_intervencion",
                   "Descripción Problema - Mantenimiento": "descripcion_problema_mantenimiento",
                   "Causa": "causa",
                   "Acción de Cierre": "accion_cierre",
                   "Especialidad Requerida": "especialidad_requerida",
                   "Repuesto Utilizado": "repuesto_utilizado",
                   "Descripción Repuesto": "descripcion_repuesto",
                   "Cantidad": "cantidad"})

# %%
KB = KB.sample(frac=0.4)

# %%
KB.columns
# Out:
# Index(['BUSINESS_UNIT', 'OT', 'localizacion', 'equipo',
#        'descripcion_problema_produccion', 'fecha_generacion',
#        'inicio_intervencion', 'fin_intervencion',
#        'descripcion_problema_mantenimiento', 'causa', 'accion_cierre',
#        'especialidad_requerida', 'repuesto_utilizado', 'descripcion_repuesto',
#        'cantidad'],
#       dtype='object')

# %%
KB[['linea', 'maquina']] = KB['localizacion'].str.split('-', n=-1, expand=True)
KB['descripcion_problema_produccion'] = KB['descripcion_problema_produccion'].str.replace('\'','')
KB['descripcion_repuesto'] = KB['descripcion_repuesto'].str.replace('\'','')

# %%
nombres[['linea', 'maquina']] = nombres['TREE_NODE'].str.split('-', n=-1, expand=True)
nombres = nombres [['linea', 'maquina', 'AJ_DESCR150', 'AJ_TIPO_LOCA_ID']]
nombres['maquina'] = nombres['maquina'].fillna('')
nombres
# Out:
# <ipython-input-203-cd6c5fe4ecbe>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nombres['maquina'] = nombres['maquina'].fillna('')
#                     linea       maquina  \
# 0    ESPTF04
# 1                 ESPTF04  DE01
# 2                 ESPTF04  DE01ME01
# 3                 ESPTF04  DE01RD01
# 4                 ESPTF04  FM01
# ..                    ...           ...
# 558               ESPTF16  TQ01RD03
# 559               ESPTF16      TQ01RD04
# 560               ESPTF16      TQ01TE01
# 561               ESPTF16      TQ01TE02
# 562               ESPTF16  TQ01TP01
#
#                                       AJ_DESCR150 AJ_TIPO_LOCA_ID
# 0                         LINEA DE TERMOFORMADO 4           LINEA
# 1                                 DESEMBOBINADOR            PADRE
# 2                           MOTOR  DESEMBOBINADOR         HIJO N1
# 3                        REDUCTOR  DESEMBOBINADOR         HIJO N1
# 4                                      FORMADORA            PADRE
# ..                                            ...             ...
# 558                  REDUCTOR LEFT TROQUEL TROQ           HIJO N1
# 559                  REDUCTOR RIGH TROQUEL TROQ           HIJO N1
# 560             CAJA DE PULSADORES TROQUEL TROQ           HIJO N1
# 561    TABLERO DE FUERZA TABLERO DE FUERZA TROQ           HIJO N1
# 562  PANEL DE PULSADORES TABLERO DE FUERZA TROQ           HIJO N1
#
# [563 rows x 4 columns]

# %%
nombres
# Out:
#                     linea       maquina  \
# 0    ESPTF04
# 1                 ESPTF04  DE01
# 2                 ESPTF04  DE01ME01
# 3                 ESPTF04  DE01RD01
# 4                 ESPTF04  FM01
# ..                    ...           ...
# 558               ESPTF16  TQ01RD03
# 559               ESPTF16      TQ01RD04
# 560               ESPTF16      TQ01TE01
# 561               ESPTF16      TQ01TE02
# 562               ESPTF16  TQ01TP01
#
#                                       AJ_DESCR150 AJ_TIPO_LOCA_ID
# 0                         LINEA DE TERMOFORMADO 4           LINEA
# 1                                 DESEMBOBINADOR            PADRE
# 2                           MOTOR  DESEMBOBINADOR         HIJO N1
# 3                        REDUCTOR  DESEMBOBINADOR         HIJO N1
# 4                                      FORMADORA            PADRE
# ..                                            ...             ...
# 558                  REDUCTOR LEFT TROQUEL TROQ           HIJO N1
# 559                  REDUCTOR RIGH TROQUEL TROQ           HIJO N1
# 560             CAJA DE PULSADORES TROQUEL TROQ           HIJO N1
# 561    TABLERO DE FUERZA TABLERO DE FUERZA TROQ           HIJO N1
# 562  PANEL DE PULSADORES TABLERO DE FUERZA TROQ           HIJO N1
#
# [563 rows x 4 columns]

# %%
lineas = nombres[nombres['AJ_TIPO_LOCA_ID'].str.contains("LINEA")]
lineas
# Out:
#                     linea maquina               AJ_DESCR150 AJ_TIPO_LOCA_ID
# 0    ESPTF04                 None   LINEA DE TERMOFORMADO 4           LINEA
# 40   ESPTF05                 None   LINEA DE TERMOFORMADO 5           LINEA
# 80   ESPTF06                 None   LINEA DE TERMOFORMADO 6           LINEA
# 98   ESPTF07                 None   LINEA DE TERMOFORMADO 7           LINEA
# 116  ESPTF10                 None  LINEA DE TERMOFORMADO 10           LINEA
# 187  ESPTF11                 None  LINEA DE TERMOFORMADO 11           LINEA
# 227  ESPTF12                 None  LINEA DE TERMOFORMADO 12           LINEA
# 277  ESPTF13                 None  LINEA DE TERMOFORMADO 13           LINEA
# 326  ESPTF14                 None  LINEA DE TERMOFORMADO 14           LINEA
# 415  ESPTF15                 None  LINEA DE TERMOFORMADO 15           LINEA
# 496  ESPTF16                 None  LINEA DE TERMOFORMADO 16           LINEA

# %%
def add_line(linea, nombre):
  query = 'CREATE (l1:Linea { id : \''+ linea +'\', nombre: \''+ nombre +'\'  }) RETURN l1'
  return query
for linea in lineas.iterrows():
  with driver.session() as session:
    info = session.run(add_line(linea[1]['linea'], linea[1]['AJ_DESCR150']))

# %%
maquinas = nombres[~nombres['AJ_TIPO_LOCA_ID'].str.contains("LINEA")]
maquinas = maquinas.drop_duplicates(subset=['maquina', 'AJ_TIPO_LOCA_ID'])
maquinas
# Out:
#        linea       maquina                                   AJ_DESCR150  \
# 1    ESPTF04  DE01                                       DESEMBOBINADOR
# 2    ESPTF04  DE01ME01                             MOTOR  DESEMBOBINADOR
# 3    ESPTF04  DE01RD01                          REDUCTOR  DESEMBOBINADOR
# 4    ESPTF04  FM01                                            FORMADORA
# 5    ESPTF04  FM01BV01                         BOMBA DE VACIO  FORMADORA
# ..       ...           ...                                           ...
# 526  ESPTF16  FM01SR02BC02                         BOMBA 2 FRIGEL FORM
# 527  ESPTF16  FM01SR02ME01                         MOTOR 1 FRIGEL FORM
# 528  ESPTF16  FM01SR02ME02                         MOTOR 2 FRIGEL FORM
# 529  ESPTF16  FM01SR02TE01                PANEL DE CONTROL FRIGEL FORM
# 562  ESPTF16  TQ01TP01      PANEL DE PULSADORES TABLERO DE FUERZA TROQ
#
#     AJ_TIPO_LOCA_ID
# 1             PADRE
# 2           HIJO N1
# 3           HIJO N1
# 4             PADRE
# 5           HIJO N1
# ..              ...
# 526         HIJO N2
# 527         HIJO N2
# 528         HIJO N2
# 529         HIJO N2
# 562         HIJO N1
#
# [182 rows x 4 columns]

# %%
def add_machine(maquina, nombre, tipo):
  query = 'CREATE (l1:Maquina { id : \''+ maquina +'\', nombre: \''+ nombre +'\', tipo : \''+ tipo +'\'  }) RETURN l1'
  return query
for maquina in maquinas.iterrows():
  with driver.session() as session:
    info = session.run(add_machine(maquina[1]['maquina'], maquina[1]['AJ_DESCR150'], maquina[1]['AJ_TIPO_LOCA_ID']))

# %%
my_array = KB['linea'].unique()
df = pd.DataFrame(my_array, columns = ['linea'])
# df = df.merge(nombres, left_on='linea', right_on='linea')
# df[df['AJ_TIPO_LOCA_ID'].str.contains("HIJO")]
df
# Out:
#       linea
# 0   ESPTF13
# 1   ESPTF10
# 2   ESPTF06
# 3   ESPTF14
# 4   ESPTF04
# 5   ESPTF05
# 6   ESPTF16
# 7   ESPTF11
# 8   ESPTF07
# 9   ESPTF15
# 10  ESPTF12

# %%
my_array = KB['maquina'].unique()
df = pd.DataFrame(my_array, columns = ['maquina'])
df = df.merge(nombres, left_on='maquina', right_on='maquina')
df
# Out:
#           maquina    linea                        AJ_DESCR150 AJ_TIPO_LOCA_ID
# 0        HF01ME01  ESPTF12   MOTOR CADENA TRANS LAMINA HORN           HIJO N1
# 1        HF01ME01  ESPTF13      MOTOR CADENA HALADORES HORN           HIJO N1
# 2        HF01ME01  ESPTF16   MOTOR CADENA TRANS LAMINA HORN           HIJO N1
# 9        FM01SR01  ESPTF05   CIRCUITO DE AGUA MOKON FORMADORA         HIJO N1
# 10       FM01SR01  ESPTF10   CIRCUITO DE AGUA MOKON FORMADORA         HIJO N1
# ..            ...      ...                                ...             ...
# 210      TQ01TP01  ESPTF04  PANEL DE PULSADORES  TROQUELADORA         HIJO N1
# 211  FM01SR01BG03  ESPTF14     BOMBA REF. RIELES MOKON FORM           HIJO N2
# 212  FM01SR01BG03  ESPTF15     BOMBA REF. RIELES MOKON FORM           HIJO N2
# 213      SP01ME03  ESPTF14                MOTOR SCRAP H. BECK         HIJO N1
# 214      SP01ME03  ESPTF15                MOTOR SCRAP H. BECK         HIJO N1
#
# [176 rows x 4 columns]

# %%
relaciones = KB.groupby(['linea','maquina']).size().reset_index()
relaciones.shape
# Out:
# (294, 3)

# %%
def add_relation(linea, maquina, cuenta):
  query = 'MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = \''+ linea +'\' AND b.id = \''+ maquina +'\' CREATE (a)-[r:TIENE {count: '+ str(cuenta) +'}]->(b) RETURN type(r), r.name'
  return query
for relacion in relaciones.iterrows():
  with driver.session() as session:
    print(relacion[0], add_relation(relacion[1]['linea'], relacion[1]['maquina'], relacion[1][0]))
    info = session.run(add_relation(relacion[1]['linea'], relacion[1]['maquina'], relacion[1][0]))
# Out:
# 0 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 22}]->(b) RETURN type(r), r.name
# 1 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 2 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 543}]->(b) RETURN type(r), r.name
# 3 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 38}]->(b) RETURN type(r), r.name
# 4 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01BV01ME01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 5 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 105}]->(b) RETURN type(r), r.name
# 6 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 49}]->(b) RETURN type(r), r.name
# 7 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01ME03' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 8 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01RD01' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 9 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 24}]->(b) RETURN type(r), r.name
# 10 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01SR01BG01' CREATE (a)-[r:TIENE {count: 12}]->(b) RETURN type(r), r.name
# 11 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01SR01BG02' CREATE (a)-[r:TIENE {count: 4}]->(b) RETURN type(r), r.name
# 12 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'FM01TE01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 13 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 109}]->(b) RETURN type(r), r.name
# 14 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 123}]->(b) RETURN type(r), r.name
# 15 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 16}]->(b) RETURN type(r), r.name
# 16 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 17 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 7}]->(b) RETURN type(r), r.name
# 18 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 638}]->(b) RETURN type(r), r.name
# 19 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 56}]->(b) RETURN type(r), r.name
# 20 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 50}]->(b) RETURN type(r), r.name
# 21 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 81}]->(b) RETURN type(r), r.name
# 22 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01RD01' CREATE (a)-[r:TIENE {count: 7}]->(b) RETURN type(r), r.name
# 23 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01RD02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 24 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 9}]->(b) RETURN type(r), r.name
# 25 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01TE01' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 26 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF04' AND b.id = 'TQ01TP01' CREATE (a)-[r:TIENE {count: 28}]->(b) RETURN type(r), r.name
# 27 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 27}]->(b) RETURN type(r), r.name
# 28 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 29 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 524}]->(b) RETURN type(r), r.name
# 30 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 16}]->(b) RETURN type(r), r.name
# 31 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01BV01ME01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 32 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 33 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 35}]->(b) RETURN type(r), r.name
# 34 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 35 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 34}]->(b) RETURN type(r), r.name
# 36 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01SR01BG01' CREATE (a)-[r:TIENE {count: 27}]->(b) RETURN type(r), r.name
# 37 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01SR01BG02' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 38 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'FM01SR01ME01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 39 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 126}]->(b) RETURN type(r), r.name
# 40 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 176}]->(b) RETURN type(r), r.name
# 41 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 33}]->(b) RETURN type(r), r.name
# 42 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 58}]->(b) RETURN type(r), r.name
# 43 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 44 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 522}]->(b) RETURN type(r), r.name
# 45 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 51}]->(b) RETURN type(r), r.name
# 46 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 20}]->(b) RETURN type(r), r.name
# 47 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 272}]->(b) RETURN type(r), r.name
# 48 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF05' AND b.id = 'TQ01RD01' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 49 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 32}]->(b) RETURN type(r), r.name
# 50 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 51 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'DE01RD01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 52 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'GL01' CREATE (a)-[r:TIENE {count: 180}]->(b) RETURN type(r), r.name
# 53 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 247}]->(b) RETURN type(r), r.name
# 54 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 58}]->(b) RETURN type(r), r.name
# 55 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'HF01RD01' CREATE (a)-[r:TIENE {count: 18}]->(b) RETURN type(r), r.name
# 56 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'HF01TE01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 57 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'HF01TE02' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 58 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'SP01' CREATE (a)-[r:TIENE {count: 155}]->(b) RETURN type(r), r.name
# 59 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'SP01TE01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 60 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 61 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 883}]->(b) RETURN type(r), r.name
# 62 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF06' AND b.id = 'TQ01SH01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 63 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 18}]->(b) RETURN type(r), r.name
# 64 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'GL01' CREATE (a)-[r:TIENE {count: 141}]->(b) RETURN type(r), r.name
# 65 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 84}]->(b) RETURN type(r), r.name
# 66 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 49}]->(b) RETURN type(r), r.name
# 67 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'HF01RD01' CREATE (a)-[r:TIENE {count: 4}]->(b) RETURN type(r), r.name
# 68 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 18}]->(b) RETURN type(r), r.name
# 69 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF07' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 316}]->(b) RETURN type(r), r.name
# 70 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 85}]->(b) RETURN type(r), r.name
# 71 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 33}]->(b) RETURN type(r), r.name
# 72 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'DE01RD01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 73 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'EX01' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 74 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'EX01BG01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 75 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 512}]->(b) RETURN type(r), r.name
# 76 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 36}]->(b) RETURN type(r), r.name
# 77 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 70}]->(b) RETURN type(r), r.name
# 78 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 91}]->(b) RETURN type(r), r.name
# 79 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01ME03' CREATE (a)-[r:TIENE {count: 34}]->(b) RETURN type(r), r.name
# 80 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01RD01' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 81 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 19}]->(b) RETURN type(r), r.name
# 82 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01SR01BG01' CREATE (a)-[r:TIENE {count: 24}]->(b) RETURN type(r), r.name
# 83 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01SR01BG02' CREATE (a)-[r:TIENE {count: 20}]->(b) RETURN type(r), r.name
# 84 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'FM01SR01ME01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 85 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 264}]->(b) RETURN type(r), r.name
# 86 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 283}]->(b) RETURN type(r), r.name
# 87 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 43}]->(b) RETURN type(r), r.name
# 88 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 27}]->(b) RETURN type(r), r.name
# 89 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'ML01RD01' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 90 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'MX01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 91 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'RH01ME02' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 92 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'RL01' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 93 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'RL01ME02' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 94 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'RL01SR01' CREATE (a)-[r:TIENE {count: 22}]->(b) RETURN type(r), r.name
# 95 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 4}]->(b) RETURN type(r), r.name
# 96 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TE01AA01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 97 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 12}]->(b) RETURN type(r), r.name
# 98 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 587}]->(b) RETURN type(r), r.name
# 99 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 10}]->(b) RETURN type(r), r.name
# 100 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 68}]->(b) RETURN type(r), r.name
# 101 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 140}]->(b) RETURN type(r), r.name
# 102 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TQ01RD01' CREATE (a)-[r:TIENE {count: 17}]->(b) RETURN type(r), r.name
# 103 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF10' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 104 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 55}]->(b) RETURN type(r), r.name
# 105 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 15}]->(b) RETURN type(r), r.name
# 106 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 536}]->(b) RETURN type(r), r.name
# 107 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 39}]->(b) RETURN type(r), r.name
# 108 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 62}]->(b) RETURN type(r), r.name
# 109 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 110 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01ME03' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 111 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 112 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01RD02' CREATE (a)-[r:TIENE {count: 33}]->(b) RETURN type(r), r.name
# 113 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 26}]->(b) RETURN type(r), r.name
# 114 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01SR01BG01' CREATE (a)-[r:TIENE {count: 35}]->(b) RETURN type(r), r.name
# 115 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01SR01BG02' CREATE (a)-[r:TIENE {count: 32}]->(b) RETURN type(r), r.name
# 116 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01SR01ME01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 117 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'FM01SR01ME02' CREATE (a)-[r:TIENE {count: 30}]->(b) RETURN type(r), r.name
# 118 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 295}]->(b) RETURN type(r), r.name
# 119 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 129}]->(b) RETURN type(r), r.name
# 120 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 30}]->(b) RETURN type(r), r.name
# 121 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 18}]->(b) RETURN type(r), r.name
# 122 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'ML01RD01' CREATE (a)-[r:TIENE {count: 4}]->(b) RETURN type(r), r.name
# 123 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 124 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TE01AA01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 125 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 126 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 538}]->(b) RETURN type(r), r.name
# 127 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 58}]->(b) RETURN type(r), r.name
# 128 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 112}]->(b) RETURN type(r), r.name
# 129 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 79}]->(b) RETURN type(r), r.name
# 130 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01RD01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 131 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 7}]->(b) RETURN type(r), r.name
# 132 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF11' AND b.id = 'TQ01TE01' CREATE (a)-[r:TIENE {count: 12}]->(b) RETURN type(r), r.name
# 133 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 176}]->(b) RETURN type(r), r.name
# 134 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 4}]->(b) RETURN type(r), r.name
# 135 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'DE01RD01' CREATE (a)-[r:TIENE {count: 28}]->(b) RETURN type(r), r.name
# 136 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 594}]->(b) RETURN type(r), r.name
# 137 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 48}]->(b) RETURN type(r), r.name
# 138 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 79}]->(b) RETURN type(r), r.name
# 139 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 15}]->(b) RETURN type(r), r.name
# 140 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'FM01RD01' CREATE (a)-[r:TIENE {count: 9}]->(b) RETURN type(r), r.name
# 141 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 62}]->(b) RETURN type(r), r.name
# 142 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 237}]->(b) RETURN type(r), r.name
# 143 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 112}]->(b) RETURN type(r), r.name
# 144 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 106}]->(b) RETURN type(r), r.name
# 145 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 146 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 53}]->(b) RETURN type(r), r.name
# 147 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'SP02' CREATE (a)-[r:TIENE {count: 23}]->(b) RETURN type(r), r.name
# 148 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'SP02ME03' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 149 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'SP02RD01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 150 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'SP02RD02' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 151 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 152 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TE01AA01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 153 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 515}]->(b) RETURN type(r), r.name
# 154 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 55}]->(b) RETURN type(r), r.name
# 155 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 61}]->(b) RETURN type(r), r.name
# 156 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 82}]->(b) RETURN type(r), r.name
# 157 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF12' AND b.id = 'TQ01TE03' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 158 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 100}]->(b) RETURN type(r), r.name
# 159 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 12}]->(b) RETURN type(r), r.name
# 160 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'DE01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 161 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 471}]->(b) RETURN type(r), r.name
# 162 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 21}]->(b) RETURN type(r), r.name
# 163 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 164 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 4}]->(b) RETURN type(r), r.name
# 165 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'FM01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 166 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 66}]->(b) RETURN type(r), r.name
# 167 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 440}]->(b) RETURN type(r), r.name
# 168 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 141}]->(b) RETURN type(r), r.name
# 169 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 83}]->(b) RETURN type(r), r.name
# 170 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 18}]->(b) RETURN type(r), r.name
# 171 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 17}]->(b) RETURN type(r), r.name
# 172 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'ML01RD01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 173 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'SP02' CREATE (a)-[r:TIENE {count: 13}]->(b) RETURN type(r), r.name
# 174 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'SP02RD02' CREATE (a)-[r:TIENE {count: 19}]->(b) RETURN type(r), r.name
# 175 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'SP02RD03' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 176 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'SP02TE01' CREATE (a)-[r:TIENE {count: 15}]->(b) RETURN type(r), r.name
# 177 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 178 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TE01AA01' CREATE (a)-[r:TIENE {count: 12}]->(b) RETURN type(r), r.name
# 179 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 180 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 453}]->(b) RETURN type(r), r.name
# 181 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 84}]->(b) RETURN type(r), r.name
# 182 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 36}]->(b) RETURN type(r), r.name
# 183 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 63}]->(b) RETURN type(r), r.name
# 184 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 18}]->(b) RETURN type(r), r.name
# 185 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF13' AND b.id = 'TQ01RD04' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 186 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 74}]->(b) RETURN type(r), r.name
# 187 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'DE01ME02' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 188 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'DE01RD02' CREATE (a)-[r:TIENE {count: 10}]->(b) RETURN type(r), r.name
# 189 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 342}]->(b) RETURN type(r), r.name
# 190 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 21}]->(b) RETURN type(r), r.name
# 191 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01BV01ME01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 192 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01BV02' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 193 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 194 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01SR01BG01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 195 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01SR01BG02' CREATE (a)-[r:TIENE {count: 15}]->(b) RETURN type(r), r.name
# 196 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01SR01BG03' CREATE (a)-[r:TIENE {count: 43}]->(b) RETURN type(r), r.name
# 197 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'FM01SR01ME02' CREATE (a)-[r:TIENE {count: 7}]->(b) RETURN type(r), r.name
# 198 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 118}]->(b) RETURN type(r), r.name
# 199 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 20}]->(b) RETURN type(r), r.name
# 200 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 203}]->(b) RETURN type(r), r.name
# 201 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 39}]->(b) RETURN type(r), r.name
# 202 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 203 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'ML01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 204 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01' CREATE (a)-[r:TIENE {count: 1154}]->(b) RETURN type(r), r.name
# 205 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01BT01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 206 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01BT02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 207 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01BT03' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 208 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01BT05ME02' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 209 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01DE01' CREATE (a)-[r:TIENE {count: 10}]->(b) RETURN type(r), r.name
# 210 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01ME01' CREATE (a)-[r:TIENE {count: 26}]->(b) RETURN type(r), r.name
# 211 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01ME02' CREATE (a)-[r:TIENE {count: 85}]->(b) RETURN type(r), r.name
# 212 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01ME03' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 213 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01RD01' CREATE (a)-[r:TIENE {count: 13}]->(b) RETURN type(r), r.name
# 214 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'SP01RD02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 215 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 216 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 820}]->(b) RETURN type(r), r.name
# 217 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01BT01' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 218 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 68}]->(b) RETURN type(r), r.name
# 219 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 7}]->(b) RETURN type(r), r.name
# 220 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 47}]->(b) RETURN type(r), r.name
# 221 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01ME04' CREATE (a)-[r:TIENE {count: 61}]->(b) RETURN type(r), r.name
# 222 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 223 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ01TE01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 224 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ02' CREATE (a)-[r:TIENE {count: 43}]->(b) RETURN type(r), r.name
# 225 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF14' AND b.id = 'TQ02ME01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 226 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 61}]->(b) RETURN type(r), r.name
# 227 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 228 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'DE01ME02' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 229 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'DE01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 230 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 652}]->(b) RETURN type(r), r.name
# 231 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 232 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 72}]->(b) RETURN type(r), r.name
# 233 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01SR01BG01' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 234 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01SR01BG02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 235 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01SR01BG03' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 236 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'FM01SR01ME01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 237 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 420}]->(b) RETURN type(r), r.name
# 238 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 54}]->(b) RETURN type(r), r.name
# 239 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 208}]->(b) RETURN type(r), r.name
# 240 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 13}]->(b) RETURN type(r), r.name
# 241 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 14}]->(b) RETURN type(r), r.name
# 242 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'ML01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 243 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01' CREATE (a)-[r:TIENE {count: 1381}]->(b) RETURN type(r), r.name
# 244 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01BT01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 245 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01BT02' CREATE (a)-[r:TIENE {count: 10}]->(b) RETURN type(r), r.name
# 246 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01BT07' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 247 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01ME01' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 248 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01ME02' CREATE (a)-[r:TIENE {count: 46}]->(b) RETURN type(r), r.name
# 249 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01RD01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 250 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01RD02' CREATE (a)-[r:TIENE {count: 14}]->(b) RETURN type(r), r.name
# 251 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01TE01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 252 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'SP01TE01AA01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 253 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TE01' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 254 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TE01AA01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 255 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 550}]->(b) RETURN type(r), r.name
# 256 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01BT01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 257 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 102}]->(b) RETURN type(r), r.name
# 258 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 9}]->(b) RETURN type(r), r.name
# 259 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 44}]->(b) RETURN type(r), r.name
# 260 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01ME04' CREATE (a)-[r:TIENE {count: 26}]->(b) RETURN type(r), r.name
# 261 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01RD01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 262 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF15' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 263 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'DE01' CREATE (a)-[r:TIENE {count: 105}]->(b) RETURN type(r), r.name
# 264 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'DE01ME01' CREATE (a)-[r:TIENE {count: 14}]->(b) RETURN type(r), r.name
# 265 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'DE01RD01' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 266 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01' CREATE (a)-[r:TIENE {count: 378}]->(b) RETURN type(r), r.name
# 267 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01BV01' CREATE (a)-[r:TIENE {count: 20}]->(b) RETURN type(r), r.name
# 268 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01BV01ME01' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 269 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01ME01' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 270 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01ME02' CREATE (a)-[r:TIENE {count: 1}]->(b) RETURN type(r), r.name
# 271 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01SR01' CREATE (a)-[r:TIENE {count: 20}]->(b) RETURN type(r), r.name
# 272 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01SR01BC01' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 273 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01SR01BC02' CREATE (a)-[r:TIENE {count: 6}]->(b) RETURN type(r), r.name
# 274 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01SR01BC03' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 275 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01SR01ME01' CREATE (a)-[r:TIENE {count: 25}]->(b) RETURN type(r), r.name
# 276 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'FM01SR01ME02' CREATE (a)-[r:TIENE {count: 3}]->(b) RETURN type(r), r.name
# 277 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'HF01' CREATE (a)-[r:TIENE {count: 461}]->(b) RETURN type(r), r.name
# 278 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'HF01ME01' CREATE (a)-[r:TIENE {count: 55}]->(b) RETURN type(r), r.name
# 279 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'ML01' CREATE (a)-[r:TIENE {count: 104}]->(b) RETURN type(r), r.name
# 280 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'ML01ME01' CREATE (a)-[r:TIENE {count: 21}]->(b) RETURN type(r), r.name
# 281 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'ML01ME02' CREATE (a)-[r:TIENE {count: 36}]->(b) RETURN type(r), r.name
# 282 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'SP01' CREATE (a)-[r:TIENE {count: 20}]->(b) RETURN type(r), r.name
# 283 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'SP01TE01' CREATE (a)-[r:TIENE {count: 15}]->(b) RETURN type(r), r.name
# 284 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'SP02' CREATE (a)-[r:TIENE {count: 5}]->(b) RETURN type(r), r.name
# 285 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TE02' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 286 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01' CREATE (a)-[r:TIENE {count: 804}]->(b) RETURN type(r), r.name
# 287 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01ME01' CREATE (a)-[r:TIENE {count: 28}]->(b) RETURN type(r), r.name
# 288 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01ME02' CREATE (a)-[r:TIENE {count: 31}]->(b) RETURN type(r), r.name
# 289 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01ME03' CREATE (a)-[r:TIENE {count: 11}]->(b) RETURN type(r), r.name
# 290 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01RD03' CREATE (a)-[r:TIENE {count: 17}]->(b) RETURN type(r), r.name
# 291 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01RD04' CREATE (a)-[r:TIENE {count: 8}]->(b) RETURN type(r), r.name
# 292 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01TE02' CREATE (a)-[r:TIENE {count: 2}]->(b) RETURN type(r), r.name
# 293 MATCH (a:Linea), (b:Maquina) WHERE trim(a.id) = 'ESPTF16' AND b.id = 'TQ01TP01' CREATE (a)-[r:TIENE {count: 14}]->(b) RETURN type(r), r.name

# %%
my_array = KB['equipo'].unique()
equipos = pd.DataFrame(my_array, columns = ['equipo'])
equipos
# Out:
#      equipo
# 0       618
# 1       468
# 2       483
# 3       457
# 4       657
# ..      ...
# 288     751
# 289     651
# 290     759
# 291     424
# 292     521
#
# [293 rows x 1 columns]

# %%
def add_equipment(equipo):
  query = 'CREATE (l1:Equipo { id : \''+ str(equipo) +'\' }) RETURN l1'
  return query
for equipo in equipos.iterrows():
  with driver.session() as session:
    info = session.run(add_equipment(equipo[1]['equipo']))

# %%
relaciones = KB.groupby(['maquina','equipo']).size().reset_index().drop_duplicates(subset=['maquina', 'equipo'])
relaciones
# Out:
#       maquina  equipo   0
# 0        DE01     376  22
# 1        DE01     411  27
# 2        DE01     446  32
# 3        DE01     458  18
# 4        DE01     468  85
# ..        ...     ...  ..
# 290  TQ01TE03     601   1
# 291  TQ01TP01     410  28
# 292  TQ01TP01     776  14
# 293      TQ02    3490  43
# 294  TQ02ME01    4399   1
#
# [295 rows x 3 columns]

# %%
problems = KB[['equipo','descripcion_problema_produccion', 'fecha_generacion', 'causa', 'especialidad_requerida']]
problems
# Out:
#        equipo descripcion_problema_produccion         fecha_generacion  \
# 0         618  Favor revisar falla de comunic  2012-09-18 13:58:15.000
# 1         468  Favor revisar desembobinador,   2012-09-18 14:39:50.000
# 2         483  Favor revisar termoformadora y  2012-09-18 15:11:29.000
# 3         457            BRAZOS NO BAJAN BIEN  2012-09-18 15:27:52.000
# 4         657  SE CAYO PARTE TRASERA DEL HORN  2012-09-18 15:31:52.000
# ...       ...                             ...                      ...
# 24381     490  Favor revisar, se está apagand  2012-01-30 09:22:25.000
# 24382     760  REVISAR ZONA 19 HORNO INF.NO C  2012-01-30 11:30:45.000
# 24383     594  REVISAR FUGA DE AIRE VALVULAS   2012-01-31 12:09:57.000
# 24384     594  REVISAR FUGA DE AIRE VALVULAS   2012-01-31 12:09:57.000
# 24385     594  REVISAR FUGA DE AIRE VALVULAS   2012-01-31 12:09:57.000
#
#                                                    causa  \
# 0                                     falla comunicacion
# 1                       DRIVE DEL DESEMBOBINADOR NO PARA
# 2                                    PRESOSTETO EN 20PSI
# 3                                               NO CORTA
# 4      RUPTURA DE TORNILLO DE LA PARTE TRASERA DEL HO...
# ...                                                  ...
# 24381                            SE APAGAN BOMBAS MOKON.
# 24382  SE REVSIA Y SE ENCUENTRA FUSIBLE ABIERTO Y SSR...
# 24383     SE SUELTAN CILINDROS DE LAS RUEDAS DEL CANOPY.
# 24384     SE SUELTAN CILINDROS DE LAS RUEDAS DEL CANOPY.
# 24385     SE SUELTAN CILINDROS DE LAS RUEDAS DEL CANOPY.
#
#       especialidad_requerida
# 0                        ELE
# 1                        ELE
# 2                        ELE
# 3                      TURNO
# 4                        MEC
# ...                      ...
# 24381                    ELE
# 24382                    ELE
# 24383                    ELE
# 24384                    ELE
# 24385                    ELE
#
# [24386 rows x 5 columns]

# %%
for pr in problems.iterrows():
  print(pr[1])
  break
# Out:
# equipo                                                        414
# descripcion_problema_produccion    REVISAR CADENA DE ARRASTRE  NO
# fecha_generacion                          2007-11-27 14:58:55.000
# causa                                           NO ARRANCA CADENA
# especialidad_requerida                                        MEC
# Name: 16383, dtype: object

# %%
solutions = KB[['equipo', 'descripcion_problema_mantenimiento','inicio_intervencion', 'fin_intervencion', 'accion_cierre', 'repuesto_utilizado', 'descripcion_repuesto','cantidad']]
solutions
# Out:
#        equipo                 descripcion_problema_mantenimiento  \
# 0         618  Favor revisar falla de comunicacion en formado...
# 1         468  Favor revisar desembobinador,      se apaga la...
# 2         483  Favor revisar termoformadora y troquel, no pre...
# 3         457                               BRAZOS NO BAJAN BIEN
# 4         657  SE CAYO PARTE TRASERA DEL HORNO INFERIOR ZONAS...
# ...       ...                                                ...
# 24381     490  Favor revisar, se está apagando el térmico de ...
# 24382     760             REVISAR ZONA 19 HORNO INF.NO CALIENTA.
# 24383     594   REVISAR FUGA DE AIRE VALVULAS DE L0S MARCADORES.
# 24384     594   REVISAR FUGA DE AIRE VALVULAS DE L0S MARCADORES.
# 24385     594   REVISAR FUGA DE AIRE VALVULAS DE L0S MARCADORES.
#
#            inicio_intervencion         fin_intervencion  \
# 0      2012-09-16 07:30:00.000  2012-09-16 07:45:00.000
# 1      2012-09-17 10:00:00.000  2012-09-17 11:20:00.000
# 2      2012-09-17 18:30:00.000  2012-09-17 20:10:00.000
# 3      2012-09-17 21:00:00.000  2012-09-17 22:00:00.000
# 4      2012-09-18 14:00:00.000  2012-09-18 16:00:00.000
# ...                        ...                      ...
# 24381  2012-01-30 07:45:00.000  2012-01-30 11:00:00.000
# 24382  2012-01-30 11:00:00.000  2012-01-30 13:00:00.000
# 24383  2012-01-31 16:00:00.000  2012-01-31 17:00:00.000
# 24384  2012-01-31 16:00:00.000  2012-01-31 17:00:00.000
# 24385  2012-01-31 16:00:00.000  2012-01-31 17:00:00.000
#
#                                            accion_cierre repuesto_utilizado  \
# 0       Se resetea ballerina y microdan arranca maquina.
# 1      SE REVISA Y SE INSTALA RELEVO A 110V PARA PARA...
# 2      SE REVISA Y SE ENCUENTRA PRESOSTETO EN 20PSI, ...
# 3      SE REVISA SE ENCUENTRA RODAMIENTO SUELTO EN LA...
# 4                     SE REVISA, SE ADICIONAN TORNILLOS.
# ...                                                  ...                ...
# 24381  SE REVSIAN CONSUMOS DE LAS BOMBA Y SE ENCUENTR...
# 24382      SE CAMBIO SSR Y FUSIBLE, SE HABILITA MAQUINA.        Z9813004002
# 24383       SE AJUSTAN CILINDROS  CON TORNILLERÍA NUEVA.
# 24384       SE AJUSTAN CILINDROS  CON TORNILLERÍA NUEVA.
# 24385       SE AJUSTAN CILINDROS  CON TORNILLERÍA NUEVA.        Z0403800006
#
#                  descripcion_repuesto cantidad
# 0                                 NaN   0.0000
# 1                                 NaN   0.0000
# 2                                 NaN   0.0000
# 3                                 NaN   0.0000
# 4                                 NaN   0.0000
# ...                               ...      ...
# 24381                             NaN   0.0000
# 24382  RELE DE ESTADO SOLIDO  MARCA O   10.000
# 24383                             NaN   0.0000
# 24384                             NaN   0.0000
# 24385  TUBING  NYLON 11    3/8in O.D.   40.000
#
# [24386 rows x 8 columns]

# %%
problemas = KB.groupby(['equipo','descripcion_problema_produccion', 'causa', 'especialidad_requerida']).size().reset_index()
problemas
# Out:
#       equipo descripcion_problema_produccion  \
# 0        376  AMPLIFICADOR DE SEÑAL NO FUNCI
# 1        376  CAMBIAR ESPEJO REFEX NO ESTA R
# 2        376   EL DESEMBOBINADDOR NO HALA LA
# 3        376  FAVOR REVISAR DESEMBOBINADOR N
# 4        376  Favor revisar el desembobinado
# ...      ...                             ...
# 8104    4196  Fuga de aceite de cilindro inf
# 8105    4198                 Cadena se frena
# 8106    4198      Hace corto una temperatura
# 8107    4379       Ruedas del Canopy pegadas
# 8108    4399  Revisar motor de las ruedas de
#
#                                                   causa  \
# 0            DESAJUSTE EN FOTOCELDAS RODILLOS HALADORES
# 1     VARIACIÓN DE SEÑAL DE ESPEJO REFLECTOR DEL DES...
# 2                            ESCOBILLA DEL MOTOR SUELTA
# 3           SE ENCUENTRA VARIADOR EN FALLA NO FUNCIONA.
# 4                   TARJETA DE CONTRO VARIADOR EN FALLA
# ...                                                 ...
# 8104                     Fuga de aceite por un cilindro
# 8105       Sensor de plancha posición superior no sensa
# 8106                                  Termocupla suelta
# 8107  Electroválvula de las ruedas del Canopy no actua.
# 8108      Motor del Canopy presenta falla en sus imanes
#
#      especialidad_requerida  0
# 0                       ELE  1
# 1                     TURNO  1
# 2                     TURNO  3
# 3                       ELE  1
# 4                       ELE  1
# ...                     ... ..
# 8104                    MEC  1
# 8105                    ELE  1
# 8106                    ELE  7
# 8107                    ELE  1
# 8108                    ELE  1
#
# [8109 rows x 5 columns]

# %%
def add_problem(id, descripcion_problema_produccion, causa, especialidad_requerida, equipo):
  query = 'CREATE (l1:Problema { id : \''+ str(id) +'\', descripcion: \''+ descripcion_problema_produccion +'\', causa : \''+ causa +'\', especialidad_requerida : \''+ especialidad_requerida +'\', equipo : \''+ str(equipo) +'\'  }) RETURN l1'
  return query
for problema in problemas.iterrows():
  with driver.session() as session:
    info = session.run(add_problem(problema[0], problema[1]['descripcion_problema_produccion'], problema[1]['causa'], problema[1]['especialidad_requerida'], problema[1]['equipo']))
# Out:
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# <ipython-input-239-dd101e2d4a3f> in <cell line: 4>()
#       4 for problema in problemas.iterrows():
#       5   with driver.session() as session:
# ----> 6     info = session.run(add_problem(problema[0], problema[1]['descripcion_problema_produccion'], problema[1]['causa'], problema[1]['especialidad_requerida'], problema[1]['equipo']))
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/work/session.py in run(self, query, parameters, **kwargs)
#     287         bookmarks = self._get_bookmarks()
#     288         parameters = dict(parameters or {}, **kwargs)
# --> 289         self._auto_result._run(
#     290             query, parameters, self._config.database,
#     291             self._config.impersonated_user, self._config.default_access_mode,
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/work/result.py in _run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_categories)
#     168         self._pull()
#     169         self._connection.send_all()
# --> 170         self._attach()
#     171
#     172     def _pull(self):
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/work/result.py in _attach(self)
#     276         if self._exhausted is False:
#     277             while self._attached is False:
# --> 278                 self._connection.fetch_message()
#     279
#     280     def _buffer(self, n=None):
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_common.py in inner(*args, **kwargs)
#     178             def inner(*args, **kwargs):
#     179                 try:
# --> 180                     func(*args, **kwargs)
#     181                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     182                     assert not asyncio.iscoroutinefunction(self.__on_error)
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     714             hydration_hooks=self.responses[0].hydration_hooks
#     715         )
# --> 716         res = self._process_message(tag, fields)
#     717         self.idle_since = perf_counter()
#     718         return res
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_bolt5.py in _process_message(self, tag, fields)
#     334             self._server_state_manager.state = ServerStates.FAILED
#     335             try:
# --> 336                 response.on_failure(summary_metadata or {})
#     337             except (ServiceUnavailable, DatabaseUnavailable):
#     338                 if self.pool:
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     245         handler = self.handlers.get("on_summary")
#     246         Util.callback(handler)
# --> 247         raise Neo4jError.hydrate(**metadata)
#     248
#     249     def on_ignored(self, metadata=None):
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'perdió': expected
#   "!="
#   "%"
#   "*"
#   "+"
#   ","
#   "-"
#   "."
#   "/"
#   ":"
#   "<"
#   "<="
#   "<>"
#   "="
#   "=~"
#   ">"
#   ">="
#   "AND"
#   "CONTAINS"
#   "ENDS"
#   "IN"
#   "IS"
#   "OR"
#   "STARTS"
#   "XOR"
#   "["
#   "^"
#   "}" (line 1, column 68 (offset: 67))
# "CREATE (l1:Problema { id : '4252', descripcion: 'Una fibra óptica 'perdió la se', causa : 'LA BAJA SENSIBILIDAD DE LA FIBRA CAUSA UN DESAJUSTE  EN EL AVANCE DE LA LAMINA EN EL TROQUEL', especialidad_requerida : 'ELE', equipo : '594'  }) RETURN l1"
#                                                                     ^}

# %%
soluciones = KB.groupby(['equipo', 'descripcion_problema_produccion','descripcion_problema_mantenimiento','inicio_intervencion', 'fin_intervencion', 'accion_cierre', 'repuesto_utilizado', 'descripcion_repuesto','cantidad']).size().reset_index()
soluciones
# Out:
#       equipo descripcion_problema_produccion  \
# 0        376  Favor revisar el desembobinado
# 1        376  Revisar desembobinador no avan
# 2        376  Revisar desembobinador no avan
# 3        376  Revisar desembobinador no avan
# 4        376  Revisar desembobinador no avan
# ...      ...                             ...
# 9330    4198      Hace corto una temperatura
# 9331    4198      Hace corto una temperatura
# 9332    4198      Hace corto una temperatura
# 9333    4198      Hace corto una temperatura
# 9334    4198      Hace corto una temperatura
#
#                      descripcion_problema_mantenimiento  \
# 0     Favor revisar el desembobinador, el motor se d...
# 1                      Revisar desembobinador no avanza
# 2                      Revisar desembobinador no avanza
# 3                      Revisar desembobinador no avanza
# 4                      Revisar desembobinador no avanza
# ...                                                 ...
# 9330                        Hace corto una temperatura
# 9331                        Hace corto una temperatura
# 9332                        Hace corto una temperatura
# 9333                        Hace corto una temperatura
# 9334                        Hace corto una temperatura
#
#           inicio_intervencion         fin_intervencion  \
# 0     2011-09-22 15:00:00.000  2011-09-22 18:45:00.000
# 1     2014-11-03 13:40:00.000  2014-11-03 15:10:00.000
# 2     2014-11-03 13:40:00.000  2014-11-03 15:10:00.000
# 3     2014-11-03 13:40:00.000  2014-11-03 15:10:00.000
# 4     2014-11-03 13:40:00.000  2014-11-03 15:10:00.000
# ...                       ...                      ...
# 9330  2023-03-11 19:41:40.880  2023-03-11 19:42:58.000
# 9331  2023-03-11 19:41:40.880  2023-03-11 19:42:58.000
# 9332  2023-03-11 19:41:40.880  2023-03-11 19:42:58.000
# 9333  2023-03-11 19:41:40.880  2023-03-11 19:42:58.000
# 9334  2023-03-11 19:41:40.880  2023-03-11 19:42:58.000
#
#                                           accion_cierre repuesto_utilizado  \
# 0              SE CAMBIO VARIADOR Y SE HABILITA MAQUINA        Z9444300016
# 1     SE HACE BORRADO Y SE PROGRAMA NUEVAMENTE, SE D...        Z0403800017
# 2     SE HACE BORRADO Y SE PROGRAMA NUEVAMENTE, SE D...        Z0500053203
# 3     SE HACE BORRADO Y SE PROGRAMA NUEVAMENTE, SE D...        Z0500800604
# 4     SE HACE BORRADO Y SE PROGRAMA NUEVAMENTE, SE D...        Z0503300006
# ...                                                 ...                ...
# 9330                              Se aprieta termocupla        Z0903200400
# 9331                              Se aprieta termocupla        Z9082000006
# 9332                              Se aprieta termocupla        Z9090124350
# 9333                              Se aprieta termocupla        Z9421140134
# 9334                              Se aprieta termocupla        Z9600100402
#
#                 descripcion_repuesto cantidad  0
# 0      VARIADOR DE VELOC. 2HP/440VAC   10.000  1
# 1     MANGUERA FLEXIBLE EN POLIURETA   20.000  1
# 2     TORNILLO BRISTOL CON CABEZA .    20.000  1
# 3     TORNILLO CABEZA HEXAGONAL - NC   60.000  1
# 4               ARANDELA PLANA 3/8``   60.000  1
# ...                              ...      ... ..
# 9330  UNION PARA CADENA SENCILLA # 4   10.000  1
# 9331  TERMINAL PLATEADO CODIGO: 6179  100.000  1
# 9332  FUSIBLE CLASE J-TIME DELAY-600   30.000  1
# 9333  TYPE J THERMOCOUPLE P/N MMJ51U   10.000  1
# 9334    RESISTENCIA INCOLOY 1/2 X 45   10.000  1
#
# [9335 rows x 10 columns]

# %%
def add_soluciones(id, descripcion_problema_produccion, descripcion_problema_mantenimiento, inicio_intervencion, equipo, fin_intervencion, accion_cierre,repuesto_utilizado, descripcion_repuesto, cantidad):
  query = 'CREATE (l1:Solucion { id : \''+ str(id) +'\', descripcion: \''+ descripcion_problema_produccion +'\', mantenimiento : \''+ descripcion_problema_mantenimiento +'\', inicio_intervencion : \''+ inicio_intervencion +'\', equipo : \''+ str(equipo) +'\', fin_intervencion : \''+ fin_intervencion +'\', accion_cierre : \''+ accion_cierre +'\', descripcion_repuesto : \''+ descripcion_repuesto +'\', cantidad : \''+ cantidad +'\' }) RETURN l1'
  return query
for solucion in soluciones.iterrows():
  with driver.session() as session:
    print(solucion[0], add_soluciones(solucion[0], solucion[1]['descripcion_problema_produccion'], solucion[1]['descripcion_problema_mantenimiento'], solucion[1]['inicio_intervencion'], solucion[1]['equipo'], solucion[1]['fin_intervencion'], solucion[1]['accion_cierre'], solucion[1]['repuesto_utilizado'], solucion[1]['descripcion_repuesto'], solucion[1]['cantidad']))
    info = session.run(add_soluciones(solucion[0], solucion[1]['descripcion_problema_produccion'], solucion[1]['descripcion_problema_mantenimiento'], solucion[1]['inicio_intervencion'], solucion[1]['equipo'], solucion[1]['fin_intervencion'], solucion[1]['accion_cierre'], solucion[1]['repuesto_utilizado'], solucion[1]['descripcion_repuesto'], solucion[1]['cantidad']))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 738 CREATE (l1:Solucion { id : '738', descripcion: 'Favor revisar el acople omega ', mantenimiento : 'Favor revisar el acople omega del motor y reductor del molde superior, tiene un ruido extraño.', inicio_intervencion : '2011-11-19 08:00:00.000', equipo : '414', fin_intervencion : '2011-11-19 08:30:00.000', accion_cierre : 'SE CAMBIO CUÑA.', descripcion_repuesto : 'TORNILLO BRISTOL SIN CABEZA -', cantidad : '10.000' }) RETURN l1
# 739 CREATE (l1:Solucion { id : '739', descripcion: 'Favor revisar el acople omega ', mantenimiento : 'Favor revisar el acople omega del motor y reductor del molde superior, tiene un ruido extraño.', inicio_intervencion : '2011-11-19 08:00:00.000', equipo : '414', fin_intervencion : '2011-11-19 08:30:00.000', accion_cierre : 'SE CAMBIO CUÑA.', descripcion_repuesto : 'TORNILLO CABEZA HEXAGONAL - NC', cantidad : '100.000' }) RETURN l1
# 740 CREATE (l1:Solucion { id : '740', descripcion: 'Favor revisar el acople omega ', mantenimiento : 'Favor revisar el acople omega del motor y reductor del molde superior, tiene un ruido extraño.', inicio_intervencion : '2011-11-19 08:00:00.000', equipo : '414', fin_intervencion : '2011-11-19 08:30:00.000', accion_cierre : 'SE CAMBIO CUÑA.', descripcion_repuesto : 'ABRAZADERA TIPO INDUSTRIAL, 28', cantidad : '60.000' }) RETURN l1
# 741 CREATE (l1:Solucion { id : '741', descripcion: 'Favor revisar el acople omega ', mantenimiento : 'Favor revisar el acople omega del motor y reductor del molde superior, tiene un ruido extraño.', inicio_intervencion : '2011-11-19 08:00:00.000', equipo : '414', fin_intervencion : '2011-11-19 08:30:00.000', accion_cierre : 'SE CAMBIO CUÑA.', descripcion_repuesto : 'DISCO CORTE PARA MOTOR TOOL DE', cantidad : '20.000' }) RETURN l1
# 742 CREATE (l1:Solucion { id : '742', descripcion: 'Favor revisar el acople omega ', mantenimiento : 'Favor revisar el acople omega del motor y reductor del molde superior, tiene un ruido extraño.', inicio_intervencion : '2011-11-19 08:00:00.000', equipo : '414', fin_intervencion : '2011-11-19 08:30:00.000', accion_cierre : 'SE CAMBIO CUÑA.', descripcion_repuesto : 'CORREA TP450H100', cantidad : '10.000' }) RETURN l1
# 743 CREATE (l1:Solucion { id : '743', descripcion: 'Favor revisar el acople omega ', mantenimiento : 'Favor revisar el acople omega del motor y reductor del molde superior, tiene un ruido extraño.', inicio_intervencion : '2011-11-19 08:00:00.000', equipo : '414', fin_intervencion : '2011-11-19 08:30:00.000', accion_cierre : 'SE CAMBIO CUÑA.', descripcion_repuesto : 'ORING - BOMBA POS. 39 -  P/N:', cantidad : '160.000' }) RETURN l1
# 744 CREATE (l1:Solucion { id : '744', descripcion: 'Favor revisar el motor del mol', mantenimiento : 'Favor revisar el motor del molde inferior, no arranca.', inicio_intervencion : '2012-08-27 12:00:00.000', equipo : '414', fin_intervencion : '2012-08-27 16:45:00.000', accion_cierre : 'SE ENCUENTRA ENCODER DAÑADO SE REALIZA CAMBIO.', descripcion_repuesto : 'ENCODER PARA HPB  IRT', cantidad : '10.000' }) RETURN l1
# 745 CREATE (l1:Solucion { id : '745', descripcion: 'Favor revisar la vàlvula del c', mantenimiento : 'Favor revisar la vàlvula del clamp trasero, no hace el cambio.', inicio_intervencion : '2010-12-06 08:06:00.000', equipo : '414', fin_intervencion : '2010-12-06 09:06:00.000', accion_cierre : 'E CAMBIO LA VÁLVULA Y SE RECONECTA CABLE DE SEÑAL DE LA VÁLVULA ESTA ABIERTO', descripcion_repuesto : 'CINTA ELECTRICA DE VINILO SUPE', cantidad : '10.000' }) RETURN l1
# 746 CREATE (l1:Solucion { id : '746', descripcion: 'Favor revisar la vàlvula del c', mantenimiento : 'Favor revisar la vàlvula del clamp trasero, no hace el cambio.', inicio_intervencion : '2010-12-06 08:06:00.000', equipo : '414', fin_intervencion : '2010-12-06 09:06:00.000', accion_cierre : 'E CAMBIO LA VÁLVULA Y SE RECONECTA CABLE DE SEÑAL DE LA VÁLVULA ESTA ABIERTO', descripcion_repuesto : 'VALVULA REF.: 811CPM-111CA-152', cantidad : '10.000' }) RETURN l1
# 747 CREATE (l1:Solucion { id : '747', descripcion: 'Favor revisar la válvula del a', mantenimiento : 'Favor revisar la válvula del aire de expulsión, se está quedando pegada.', inicio_intervencion : '2012-05-23 08:30:00.000', equipo : '414', fin_intervencion : '2012-05-23 09:00:00.000', accion_cierre : 'ACTUADOR DAÑADO, SE CAMBIA ACTUADOR DE LA VALVULA', descripcion_repuesto : 'KIT DE REPARACIÓN PARA VÁLVULA', cantidad : '10.000' }) RETURN l1
# 748 CREATE (l1:Solucion { id : '748', descripcion: 'Favor revisar válvula de desfo', mantenimiento : 'Favor revisar válvula de desfogue', inicio_intervencion : '2021-04-15 11:55:53.610', equipo : '414', fin_intervencion : '2021-04-15 11:57:53.000', accion_cierre : 'Se realiza cambio de actuador y se habilita', descripcion_repuesto : 'VALVULA SOLENOIDE MAC 250B-111', cantidad : '10.000' }) RETURN l1
# 749 CREATE (l1:Solucion { id : '749', descripcion: 'Formadora no arranca', mantenimiento : 'Formadora no arranca', inicio_intervencion : '2020-08-28 16:46:10.230', equipo : '414', fin_intervencion : '2020-08-28 19:05:22.000', accion_cierre : 'Se realiza ajuste de coonecciones de del microphesser', descripcion_repuesto : 'AEROSOL CONTAC CLEANER LIMPIAD', cantidad : '10.000' }) RETURN l1
# 750 CREATE (l1:Solucion { id : '750', descripcion: 'Hacer cambio de cadenas', mantenimiento : 'Hacer cambio de cadenas', inicio_intervencion : '2016-07-25 07:29:00.000', equipo : '414', fin_intervencion : '2016-07-25 16:29:00.000', accion_cierre : 'se realiza cambio de cadenas por unas usadas que se encontraban en la tf 16 que eran de rígidos', descripcion_repuesto : 'ACEITE LUBRICANTE ADHERENTE CO', cantidad : '10.000' }) RETURN l1
# 751 CREATE (l1:Solucion { id : '751', descripcion: 'Hacer cambio de cadenas', mantenimiento : 'Hacer cambio de cadenas', inicio_intervencion : '2016-07-25 07:29:00.000', equipo : '414', fin_intervencion : '2016-07-25 16:29:00.000', accion_cierre : 'se realiza cambio de cadenas por unas usadas que se encontraban en la tf 16 que eran de rígidos', descripcion_repuesto : 'UNION CADENA RSD 40-1', cantidad : '30.000' }) RETURN l1
# 752 CREATE (l1:Solucion { id : '752', descripcion: 'Hacer cambio de cadenas', mantenimiento : 'Hacer cambio de cadenas', inicio_intervencion : '2016-07-25 07:29:00.000', equipo : '414', fin_intervencion : '2016-07-25 16:29:00.000', accion_cierre : 'se realiza cambio de cadenas por unas usadas que se encontraban en la tf 16 que eran de rígidos', descripcion_repuesto : 'UNION MEDIO PASO CADENA RSD 40', cantidad : '30.000' }) RETURN l1
# 753 CREATE (l1:Solucion { id : '753', descripcion: 'Hacer cambio de cadenas', mantenimiento : 'Hacer cambio de cadenas', inicio_intervencion : '2016-07-25 07:29:00.000', equipo : '414', fin_intervencion : '2016-07-25 16:29:00.000', accion_cierre : 'se realiza cambio de cadenas por unas usadas que se encontraban en la tf 16 que eran de rígidos', descripcion_repuesto : 'UNION PARA CADENA SENCILLA # 4', cantidad : '20.000' }) RETURN l1
# 754 CREATE (l1:Solucion { id : '754', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'VARSOL', cantidad : '50.000' }) RETURN l1
# 755 CREATE (l1:Solucion { id : '755', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'SILICONA TRANSPARENTE SUPERFLE', cantidad : '10.000' }) RETURN l1
# 756 CREATE (l1:Solucion { id : '756', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'MANGUERA DE CAUCHO DIA 1/2`` P', cantidad : '30.000' }) RETURN l1
# 757 CREATE (l1:Solucion { id : '757', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'ARANDELA PLANA 3/4``', cantidad : '10.000' }) RETURN l1
# 758 CREATE (l1:Solucion { id : '758', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'SEGUETA PARA CALADORA CORTE DE', cantidad : '20.000' }) RETURN l1
# 759 CREATE (l1:Solucion { id : '759', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'FILTRO DE ACEITE REF.: ML1098', cantidad : '10.000' }) RETURN l1
# 760 CREATE (l1:Solucion { id : '760', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'KIT OVERHAUL FOR VACUUM PUMP B', cantidad : '10.000' }) RETURN l1
# 761 CREATE (l1:Solucion { id : '761', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'EXHAUST FILTER- REF:120 FOR VA', cantidad : '30.000' }) RETURN l1
# 762 CREATE (l1:Solucion { id : '762', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'BAFFLE STRAINER- REF NO. 130 F', cantidad : '10.000' }) RETURN l1
# 763 CREATE (l1:Solucion { id : '763', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'POLEA EN ALUMINIO DE 24 DIENTE', cantidad : '10.000' }) RETURN l1
# 764 CREATE (l1:Solucion { id : '764', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'SERVO BOARD REF: ELE-204 FOR T', cantidad : '10.000' }) RETURN l1
# 765 CREATE (l1:Solucion { id : '765', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'MPII DISPLAY  REF: ELE-215', cantidad : '10.000' }) RETURN l1
# 766 CREATE (l1:Solucion { id : '766', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'TRIPLE OUTPUT POWER SUPPLY CAB', cantidad : '10.000' }) RETURN l1
# 767 CREATE (l1:Solucion { id : '767', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'FAN PLASTIC- FOR UNIMOUNT MODE', cantidad : '10.000' }) RETURN l1
# 768 CREATE (l1:Solucion { id : '768', descripcion: 'LA FORMADORA SE CONTINUA APAGA', mantenimiento : 'LA FORMADORA SE CONTINUA APAGANDO Y LOS MARCADORES NO ESTAQN FUNCIONANDO', inicio_intervencion : '2010-11-30 12:00:00.000', equipo : '414', fin_intervencion : '2010-11-30 14:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA LOS DRIVES DE LOS MOTORES CALIENTES , SE MEJORA LA REFRIGERACION DE L TABLERO DE LOS DRIVES, QUEDA OPERATIVA LA MAQUINA', descripcion_repuesto : 'BLOWER 115V, 60 HZ, RPM 2450 P', cantidad : '10.000' }) RETURN l1
# 769 CREATE (l1:Solucion { id : '769', descripcion: 'Micro de la puerta frontal de ', mantenimiento : 'Micro de la puerta frontal de la formadora está fallando', inicio_intervencion : '2021-03-29 02:07:00.000', equipo : '414', fin_intervencion : '2021-03-29 03:07:00.000', accion_cierre : 'Se realiza mantenimiento', descripcion_repuesto : 'ACOPLE RAPIDO ROSCADO TIPO  1/', cantidad : '40.000' }) RETURN l1
# 770 CREATE (l1:Solucion { id : '770', descripcion: 'Micro de la puerta frontal de ', mantenimiento : 'Micro de la puerta frontal de la formadora está fallando', inicio_intervencion : '2021-03-29 02:07:00.000', equipo : '414', fin_intervencion : '2021-03-29 03:07:00.000', accion_cierre : 'Se realiza mantenimiento', descripcion_repuesto : 'ACOPLE RAPIDO ROSCADO TIPO  3/', cantidad : '20.000' }) RETURN l1
# 771 CREATE (l1:Solucion { id : '771', descripcion: 'Micro de la puerta frontal de ', mantenimiento : 'Micro de la puerta frontal de la formadora está fallando', inicio_intervencion : '2021-03-29 02:07:00.000', equipo : '414', fin_intervencion : '2021-03-29 03:07:00.000', accion_cierre : 'Se realiza mantenimiento', descripcion_repuesto : 'BROCA ACERO RAPIDO 13/64', cantidad : '10.000' }) RETURN l1
# 772 CREATE (l1:Solucion { id : '772', descripcion: 'Micro de la puerta frontal de ', mantenimiento : 'Micro de la puerta frontal de la formadora está fallando', inicio_intervencion : '2021-03-29 02:07:00.000', equipo : '414', fin_intervencion : '2021-03-29 03:07:00.000', accion_cierre : 'Se realiza mantenimiento', descripcion_repuesto : 'FUSIBLES FAST ACTING DE 5 X 20', cantidad : '50.000' }) RETURN l1
# 773 CREATE (l1:Solucion { id : '773', descripcion: 'Micro de la puerta frontal de ', mantenimiento : 'Micro de la puerta frontal de la formadora está fallando', inicio_intervencion : '2021-03-29 02:07:00.000', equipo : '414', fin_intervencion : '2021-03-29 03:07:00.000', accion_cierre : 'Se realiza mantenimiento', descripcion_repuesto : 'FUSIBLE PICO FUSE 5 AMP', cantidad : '30.000' }) RETURN l1
# 774 CREATE (l1:Solucion { id : '774', descripcion: 'Micro de la puerta frontal de ', mantenimiento : 'Micro de la puerta frontal de la formadora está fallando', inicio_intervencion : '2021-03-29 02:07:00.000', equipo : '414', fin_intervencion : '2021-03-29 03:07:00.000', accion_cierre : 'Se realiza mantenimiento', descripcion_repuesto : 'BORNA PORTAFUSIBLE 281-611. WA', cantidad : '10.000' }) RETURN l1
# 775 CREATE (l1:Solucion { id : '775', descripcion: 'REVISAR BOMBA DEL VACIO SE APA', mantenimiento : 'REVISAR BOMBA DEL VACIO SE APAGO', inicio_intervencion : '2014-03-12 07:30:00.000', equipo : '414', fin_intervencion : '2014-03-12 08:30:00.000', accion_cierre : 'SE CAMBIO TENMPORIZADOR EN MAL ESTADO.', descripcion_repuesto : 'TUBING PARA LUBRICACION (ALTA ', cantidad : '100.000' }) RETURN l1
# 776 CREATE (l1:Solucion { id : '776', descripcion: 'REVISAR BOMBA DEL VACIO SE APA', mantenimiento : 'REVISAR BOMBA DEL VACIO SE APAGO', inicio_intervencion : '2014-03-12 07:30:00.000', equipo : '414', fin_intervencion : '2014-03-12 08:30:00.000', accion_cierre : 'SE CAMBIO TENMPORIZADOR EN MAL ESTADO.', descripcion_repuesto : 'TEMPORIZADOR ELECTRONICO 700FS', cantidad : '10.000' }) RETURN l1
# 777 CREATE (l1:Solucion { id : '777', descripcion: 'REVISAR BOMBA DEL VACIO SE APA', mantenimiento : 'REVISAR BOMBA DEL VACIO SE APAGO', inicio_intervencion : '2014-03-12 07:30:00.000', equipo : '414', fin_intervencion : '2014-03-12 08:30:00.000', accion_cierre : 'SE CAMBIO TENMPORIZADOR EN MAL ESTADO.', descripcion_repuesto : 'AISLANTE DE NYLON TIPO TUERCA.', cantidad : '120.000' }) RETURN l1
# 778 CREATE (l1:Solucion { id : '778', descripcion: 'REVISAR BOMBA DEL VACIO SE APA', mantenimiento : 'REVISAR BOMBA DEL VACIO SE APAGO', inicio_intervencion : '2014-03-12 07:30:00.000', equipo : '414', fin_intervencion : '2014-03-12 08:30:00.000', accion_cierre : 'SE CAMBIO TENMPORIZADOR EN MAL ESTADO.', descripcion_repuesto : 'AISLANTE DE NYLON TIPO TUERCA.', cantidad : '120.000' }) RETURN l1
# 779 CREATE (l1:Solucion { id : '779', descripcion: 'REVISAR FORMADFORA SE APAGO', mantenimiento : 'REVISAR FORMADFORA SE APAGO', inicio_intervencion : '2010-03-24 10:00:00.000', equipo : '414', fin_intervencion : '2010-03-24 11:00:00.000', accion_cierre : 'SE REVISA PARAMETRO DE APERTURA', descripcion_repuesto : 'AEROSOL CONTAC CLEANER LIMPIAD', cantidad : '20.000' }) RETURN l1
# 780 CREATE (l1:Solucion { id : '780', descripcion: 'REVISAR FORMADFORA SE APAGO', mantenimiento : 'REVISAR FORMADFORA SE APAGO', inicio_intervencion : '2010-03-24 10:00:00.000', equipo : '414', fin_intervencion : '2010-03-24 11:00:00.000', accion_cierre : 'SE REVISA PARAMETRO DE APERTURA', descripcion_repuesto : 'CINTA DE TEFLON DE FIBRA 3/4``', cantidad : '10.000' }) RETURN l1
# 781 CREATE (l1:Solucion { id : '781', descripcion: 'REVISAR FORMADORA  SE APAGA EN', mantenimiento : 'REVISAR FORMADORA  SE APAGA EN VARIAS VESES Y SDE ABRE EL HORNO', inicio_intervencion : '2008-03-08 04:00:00.000', equipo : '414', fin_intervencion : '2008-03-08 05:00:00.000', accion_cierre : 'SE RVISA MOTOR DEL MOLDE SUPERIOR', descripcion_repuesto : 'ACEITE PENETRANTE INDUSTRIAL C', cantidad : '20.000' }) RETURN l1
# 782 CREATE (l1:Solucion { id : '782', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'AEROSOL CONTAC CLEANER LIMPIAD', cantidad : '40.000' }) RETURN l1
# 783 CREATE (l1:Solucion { id : '783', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'CODO METALICO 1/8 NPT X 1/8IN', cantidad : '60.000' }) RETURN l1
# 784 CREATE (l1:Solucion { id : '784', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'RODAMIENTO RIGIDO DE UNA HILER', cantidad : '20.000' }) RETURN l1
# 785 CREATE (l1:Solucion { id : '785', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'SELLO MECANICO 1" MONORESORTE ', cantidad : '10.000' }) RETURN l1
# 786 CREATE (l1:Solucion { id : '786', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'RESISTENCIA FERRONÍQUEL PLANO ', cantidad : '40.000' }) RETURN l1
# 787 CREATE (l1:Solucion { id : '787', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'TUBULAR HEATER MODEL 28 Ref: H', cantidad : '10.000' }) RETURN l1
# 788 CREATE (l1:Solucion { id : '788', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'CONTACTOR. 3 POLOS. 50A. BOBIN', cantidad : '10.000' }) RETURN l1
# 789 CREATE (l1:Solucion { id : '789', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'BOMBILLA PILOTO 130 V 20 Ref:', cantidad : '20.000' }) RETURN l1
# 790 CREATE (l1:Solucion { id : '790', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'CONTACT BLOCK 1 NC  P/N 9001-K', cantidad : '10.000' }) RETURN l1
# 791 CREATE (l1:Solucion { id : '791', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'CABLE RIBBON 60 LINEAS MULTICO', cantidad : '100.000' }) RETURN l1
# 792 CREATE (l1:Solucion { id : '792', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'FUSIBLE SUPLEMENTARIO 1-1/2``x', cantidad : '60.000' }) RETURN l1
# 793 CREATE (l1:Solucion { id : '793', descripcion: 'REVISAR FORMADORA SE ESTA APAG', mantenimiento : 'REVISAR FORMADORA SE ESTA APAGANDO', inicio_intervencion : '2010-11-13 09:00:00.000', equipo : '414', fin_intervencion : '2010-11-13 10:00:00.000', accion_cierre : 'SE REVISA, SE ENCUENTRA MICROPHASER CALIENTE, SE AJUSTAN TARJETAS Y CONEXIONES, SE ENFRIA EL MICROPHASER, QUEDA OPERANDO BIEN LA MAQUINA', descripcion_repuesto : 'RELAY; SSR; ZERO-SWITCHING; SP', cantidad : '20.000' }) RETURN l1
# 794 CREATE (l1:Solucion { id : '794', descripcion: 'REVISAR FORMADORA SE QUEDO FRE', mantenimiento : 'REVISAR FORMADORA SE QUEDO FRENADA LA CADENA', inicio_intervencion : '2010-04-12 18:00:00.000', equipo : '414', fin_intervencion : '2010-04-12 19:00:00.000', accion_cierre : 'SE REVISAN CONTACTORES Y SE CAMBIO LA POLEA DEL ENCODER.', descripcion_repuesto : 'CORREA DENTADA  210 XL 037', cantidad : '10.000' }) RETURN l1
# 795 CREATE (l1:Solucion { id : '795', descripcion: 'REVISAR FORMADORA SE QUEDO FRE', mantenimiento : 'REVISAR FORMADORA SE QUEDO FRENADA LA CADENA', inicio_intervencion : '2010-04-12 18:00:00.000', equipo : '414', fin_intervencion : '2010-04-12 19:00:00.000', accion_cierre : 'SE REVISAN CONTACTORES Y SE CAMBIO LA POLEA DEL ENCODER.', descripcion_repuesto : 'POLEA EN ALUMINIO DE 24 DIENTE', cantidad : '10.000' }) RETURN l1
# 796 CREATE (l1:Solucion { id : '796', descripcion: 'REVISAR FORMADORA Y TROQUEL SE', mantenimiento : 'REVISAR FORMADORA Y TROQUEL SE BLOQUEAN', inicio_intervencion : '2010-04-10 18:00:00.000', equipo : '414', fin_intervencion : '2010-04-10 18:30:00.000', accion_cierre : '4/10/10', descripcion_repuesto : 'ABRAZADERA EN ACERO INOXIDABLE', cantidad : '20.000' }) RETURN l1
# 797 CREATE (l1:Solucion { id : '797', descripcion: 'REVISAR MOLDES NO POSECIONAN', mantenimiento : 'REVISAR MOLDES NO POSECIONAN', inicio_intervencion : '2008-09-06 05:00:00.000', equipo : '414', fin_intervencion : '2008-09-06 05:30:00.000', accion_cierre : 'SE EXTRAE MATERIAL DE LA CADENA.', descripcion_repuesto : 'TUERCA HEXAGONAL DE 1/4 NF DE', cantidad : '100.000' }) RETURN l1
# 798 CREATE (l1:Solucion { id : '798', descripcion: 'REVISAR MOLDES NO POSECIONAN', mantenimiento : 'REVISAR MOLDES NO POSECIONAN', inicio_intervencion : '2008-09-06 05:00:00.000', equipo : '414', fin_intervencion : '2008-09-06 05:30:00.000', accion_cierre : 'SE EXTRAE MATERIAL DE LA CADENA.', descripcion_repuesto : 'RODAMIENTO RIGIDO DE UNA HILER', cantidad : '10.000' }) RETURN l1
# 799 CREATE (l1:Solucion { id : '799', descripcion: 'REVISAR MOLDES NO POSECIONAN', mantenimiento : 'REVISAR MOLDES NO POSECIONAN', inicio_intervencion : '2008-09-06 05:00:00.000', equipo : '414', fin_intervencion : '2008-09-06 05:30:00.000', accion_cierre : 'SE EXTRAE MATERIAL DE LA CADENA.', descripcion_repuesto : 'RODAMIENTO RIGIDO DE UNA HILER', cantidad : '10.000' }) RETURN l1
# 800 CREATE (l1:Solucion { id : '800', descripcion: 'REVISAR SISTEMA DE LUBRICACION', mantenimiento : 'REVISAR SISTEMA DE LUBRICACION DE LA FORMADORA TIENE FUGA', inicio_intervencion : '2011-08-20 10:00:00.000', equipo : '414', fin_intervencion : '2011-08-20 11:00:00.000', accion_cierre : 'SE COLOCAN ARANDELAS EN BRONSE Y S ECORRIGE FUGA.', descripcion_repuesto : 'RELAY (120 VAC, DPDT) P/N LY2A', cantidad : '10.000' }) RETURN l1
# 801 CREATE (l1:Solucion { id : '801', descripcion: 'REVISAR SISTEMA DE LUBRICACION', mantenimiento : 'REVISAR SISTEMA DE LUBRICACION DE LA FORMADORA TIENE FUGA', inicio_intervencion : '2011-08-20 10:00:00.000', equipo : '414', fin_intervencion : '2011-08-20 11:00:00.000', accion_cierre : 'SE COLOCAN ARANDELAS EN BRONSE Y S ECORRIGE FUGA.', descripcion_repuesto : 'BLOQUE DE CONTACTOS SQUARE D R', cantidad : '30.000' }) RETURN l1
# 802 CREATE (l1:Solucion { id : '802', descripcion: 'REVISAR SISTEMA DE LUBRICACION', mantenimiento : 'REVISAR SISTEMA DE LUBRICACION DE LA FORMADORA TIENE FUGA', inicio_intervencion : '2011-08-20 10:00:00.000', equipo : '414', fin_intervencion : '2011-08-20 11:00:00.000', accion_cierre : 'SE COLOCAN ARANDELAS EN BRONSE Y S ECORRIGE FUGA.', descripcion_repuesto : 'BASE PARA RELEVO 8 PINES PLANO', cantidad : '10.000' }) RETURN l1
# 803 CREATE (l1:Solucion { id : '803', descripcion: 'REVISAR VALVULA DE EXPULSION S', mantenimiento : 'REVISAR VALVULA DE EXPULSION SE QUEDA PEGADA', inicio_intervencion : '2013-12-19 21:17:00.000', equipo : '414', fin_intervencion : '2013-12-19 22:37:00.000', accion_cierre : 'SE BAJAN VALVULAS DE EXPULSION Y VACIO Y SE LES HACE MANTENIMIENTO;SE ENCUENTRA PILOTAJE DE LA VALVULA DE EXPULSION DAÑADO, SE SACA DEL ALMACEN UNO NUEVO Y SE CAMBIA', descripcion_repuesto : 'ELECTROVALVULA MAC 225B-111CAA', cantidad : '10.000' }) RETURN l1
# 804 CREATE (l1:Solucion { id : '804', descripcion: 'REVISAR VALVULA DE VACIO,POR Q', mantenimiento : 'REVISAR VALVULA DE VACIO,POR QUE ESTA QUEDANDO PEGADA.', inicio_intervencion : '2014-07-30 08:00:00.000', equipo : '414', fin_intervencion : '2014-07-30 09:00:00.000', accion_cierre : 'SE CAMBIAN ACTUADORES Y SE ENCUENTRA QUE LA MANGUERA ESTABA EXTRANGULADA, SE CAMBIO MANGUERA', descripcion_repuesto : 'VALVULA SOLENOIDE MAC 250B-111', cantidad : '20.000' }) RETURN l1
# 805 CREATE (l1:Solucion { id : '805', descripcion: 'REVIsar formadora se apaga sol', mantenimiento : 'REVIsar formadora se apaga sola', inicio_intervencion : '2010-04-01 09:30:00.000', equipo : '414', fin_intervencion : '2010-04-01 10:30:00.000', accion_cierre : 'SE CAMBIO MEMORIA RAM', descripcion_repuesto : 'CINTA ELECTRICA TELA DE VIDRIO', cantidad : '10.000' }) RETURN l1
# 806 CREATE (l1:Solucion { id : '806', descripcion: 'REVIsar formadora se apaga sol', mantenimiento : 'REVIsar formadora se apaga sola', inicio_intervencion : '2010-04-01 09:30:00.000', equipo : '414', fin_intervencion : '2010-04-01 10:30:00.000', accion_cierre : 'SE CAMBIO MEMORIA RAM', descripcion_repuesto : 'FUSIBLES FAST ACTING DE 5 X 20', cantidad : '50.000' }) RETURN l1
# 807 CREATE (l1:Solucion { id : '807', descripcion: 'REVIsar formadora se apaga sol', mantenimiento : 'REVIsar formadora se apaga sola', inicio_intervencion : '2010-04-01 09:30:00.000', equipo : '414', fin_intervencion : '2010-04-01 10:30:00.000', accion_cierre : 'SE CAMBIO MEMORIA RAM', descripcion_repuesto : 'BRUSH P/N 83-186221', cantidad : '80.000' }) RETURN l1
# 808 CREATE (l1:Solucion { id : '808', descripcion: 'Revisar cadena lado derecho. C', mantenimiento : 'Revisar cadena lado derecho. Cortar 1 paso', inicio_intervencion : '2019-08-05 18:08:00.000', equipo : '414', fin_intervencion : '2019-08-05 19:08:00.000', accion_cierre : 'se recorta un paso de la cadena se arma nuevamente', descripcion_repuesto : 'OVEROL O VESTIDO TYVEK REF.695', cantidad : '10.000' }) RETURN l1
# 809 CREATE (l1:Solucion { id : '809', descripcion: 'Revisar cadena lado derecho. C', mantenimiento : 'Revisar cadena lado derecho. Cortar 1 paso', inicio_intervencion : '2019-08-05 18:08:00.000', equipo : '414', fin_intervencion : '2019-08-05 19:08:00.000', accion_cierre : 'se recorta un paso de la cadena se arma nuevamente', descripcion_repuesto : 'TORNILLO CABEZA HEXAGONAL . NC', cantidad : '10.000' }) RETURN l1
# 810 CREATE (l1:Solucion { id : '810', descripcion: 'Revisar cadena lado derecho. C', mantenimiento : 'Revisar cadena lado derecho. Cortar 1 paso', inicio_intervencion : '2019-08-05 18:08:00.000', equipo : '414', fin_intervencion : '2019-08-05 19:08:00.000', accion_cierre : 'se recorta un paso de la cadena se arma nuevamente', descripcion_repuesto : 'TUERCA DE SEGURIDAD-NC 1/4``', cantidad : '10.000' }) RETURN l1
# 811 CREATE (l1:Solucion { id : '811', descripcion: 'Revisar cadena lado derecho. C', mantenimiento : 'Revisar cadena lado derecho. Cortar 1 paso', inicio_intervencion : '2019-08-05 18:08:00.000', equipo : '414', fin_intervencion : '2019-08-05 19:08:00.000', accion_cierre : 'se recorta un paso de la cadena se arma nuevamente', descripcion_repuesto : 'ARANDELA PLANA 1/4``- GALVANIZ', cantidad : '20.000' }) RETURN l1
# 812 CREATE (l1:Solucion { id : '812', descripcion: 'Revisar cadena lado derecho. C', mantenimiento : 'Revisar cadena lado derecho. Cortar 1 paso', inicio_intervencion : '2019-08-05 18:08:00.000', equipo : '414', fin_intervencion : '2019-08-05 19:08:00.000', accion_cierre : 'se recorta un paso de la cadena se arma nuevamente', descripcion_repuesto : 'DISCO CORTE PARA MOTOR TOOL DE', cantidad : '10.000' }) RETURN l1
# 813 CREATE (l1:Solucion { id : '813', descripcion: 'Revisar cadena lado derecho. C', mantenimiento : 'Revisar cadena lado derecho. Cortar 1 paso', inicio_intervencion : '2019-08-05 18:08:00.000', equipo : '414', fin_intervencion : '2019-08-05 19:08:00.000', accion_cierre : 'se recorta un paso de la cadena se arma nuevamente', descripcion_repuesto : 'FIL. ASSY. BLWR 3-4`` PLEATED ', cantidad : '10.000' }) RETURN l1
# 814 CREATE (l1:Solucion { id : '814', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'CINTA DE TEFLON DE FIBRA 3/4``', cantidad : '10.000' }) RETURN l1
# 815 CREATE (l1:Solucion { id : '815', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'CINTA DE TEFLON INDUSTRIAL PAR', cantidad : '10.000' }) RETURN l1
# 816 CREATE (l1:Solucion { id : '816', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'SILICONA TRANSPARENTE SUPERFLE', cantidad : '10.000' }) RETURN l1
# 817 CREATE (l1:Solucion { id : '817', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'SOLDADURA 680 DE 3/32Inch /  R', cantidad : '0.2500' }) RETURN l1
# 818 CREATE (l1:Solucion { id : '818', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TORNILLO BRISTOL CON CABEZA - ', cantidad : '20.000' }) RETURN l1
# 819 CREATE (l1:Solucion { id : '819', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TORNILLO BRISTOL CON CABEZA -', cantidad : '20.000' }) RETURN l1
# 820 CREATE (l1:Solucion { id : '820', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TORNILLO CABEZA HEXAGONAL - NC', cantidad : '30.000' }) RETURN l1
# 821 CREATE (l1:Solucion { id : '821', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TORNILLO CABEZA HEXAGONAL. NC.', cantidad : '40.000' }) RETURN l1
# 822 CREATE (l1:Solucion { id : '822', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TUERCA HEXAGONAL-NC 3/8``', cantidad : '40.000' }) RETURN l1
# 823 CREATE (l1:Solucion { id : '823', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'QSML-M5-6  RACOR RAPIDO ROSCAD', cantidad : '10.000' }) RETURN l1
# 824 CREATE (l1:Solucion { id : '824', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TEE DE UNION MANGUERA - MANGUE', cantidad : '10.000' }) RETURN l1
# 825 CREATE (l1:Solucion { id : '825', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'UNION PARA CADENA SENCILLA # 4', cantidad : '40.000' }) RETURN l1
# 826 CREATE (l1:Solucion { id : '826', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'UNION MEDIO PASO PARA CADENA S', cantidad : '20.000' }) RETURN l1
# 827 CREATE (l1:Solucion { id : '827', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'DRIVE WHEEL HUB P/N TP11326', cantidad : '10.000' }) RETURN l1
# 828 CREATE (l1:Solucion { id : '828', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'CARCAZA EMPOTRADA HCD7 AML-24/', cantidad : '10.000' }) RETURN l1
# 829 CREATE (l1:Solucion { id : '829', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'CARCAZA AEREA HC-STA-D07-HHFS-', cantidad : '10.000' }) RETURN l1
# 830 CREATE (l1:Solucion { id : '830', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'BORNE HEMBRA HC-A04-I-UT-F No.', cantidad : '10.000' }) RETURN l1
# 831 CREATE (l1:Solucion { id : '831', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'BORNE MACHO HC-A04-I-UT-M  REF', cantidad : '10.000' }) RETURN l1
# 832 CREATE (l1:Solucion { id : '832', descripcion: 'Revisar se apaga formadora', mantenimiento : 'Revisar se apaga formadora', inicio_intervencion : '2015-01-31 11:30:00.000', equipo : '414', fin_intervencion : '2015-01-31 12:30:00.000', accion_cierre : 'SE CAMBIAN BORNES EN MAL ESTADO Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'ABSOLUTE ENCODER SIZE 25  P/N ', cantidad : '10.000' }) RETURN l1
# 833 CREATE (l1:Solucion { id : '833', descripcion: 'Revisar válvula de expulsión d', mantenimiento : 'Revisar válvula de expulsión de, queda pegada', inicio_intervencion : '2020-10-18 04:41:37.213', equipo : '414', fin_intervencion : '2020-10-18 04:44:31.000', accion_cierre : 'Se realiza mantenimiento y se cambia actuador', descripcion_repuesto : 'VALVULA SOLENOIDE MAC 250B-111', cantidad : '10.000' }) RETURN l1
# 834 CREATE (l1:Solucion { id : '834', descripcion: 'Revisar válvula de expulsión d', mantenimiento : 'Revisar válvula de expulsión de, queda pegada', inicio_intervencion : '2020-10-18 04:41:37.213', equipo : '414', fin_intervencion : '2020-10-18 04:44:31.000', accion_cierre : 'Se realiza mantenimiento y se cambia actuador', descripcion_repuesto : 'E1 PLUS SOLID STATE OVERLOAD R', cantidad : '10.000' }) RETURN l1
# 835 CREATE (l1:Solucion { id : '835', descripcion: 'Rodamiento dañado de un brazo', mantenimiento : 'Rodamiento dañado de un brazo de la formadora', inicio_intervencion : '2022-01-31 11:16:38.483', equipo : '414', fin_intervencion : '2022-01-31 11:21:17.000', accion_cierre : 'Se cambia tornillo del brazo superior izquierdo y se entrega', descripcion_repuesto : 'CLORURO DE METILENO', cantidad : '70.000' }) RETURN l1
# 836 CREATE (l1:Solucion { id : '836', descripcion: 'Rodamiento dañado de un brazo', mantenimiento : 'Rodamiento dañado de un brazo de la formadora', inicio_intervencion : '2022-01-31 11:16:38.483', equipo : '414', fin_intervencion : '2022-01-31 11:21:17.000', accion_cierre : 'Se cambia tornillo del brazo superior izquierdo y se entrega', descripcion_repuesto : 'TORNILLO BRISTOL CON CABEZA -', cantidad : '40.000' }) RETURN l1
# 837 CREATE (l1:Solucion { id : '837', descripcion: 'Rodamiento suelto', mantenimiento : 'Rodamiento suelto', inicio_intervencion : '2021-09-02 20:47:02.370', equipo : '414', fin_intervencion : '2021-09-02 21:16:33.000', accion_cierre : ' Se ajusta tornillo del molde superior', descripcion_repuesto : 'REBUILT KIT FOR VICKERS VALVE', cantidad : '10.000' }) RETURN l1
# 838 CREATE (l1:Solucion { id : '838', descripcion: 'SE APAGA FORMADORA Y SE ABRE E', mantenimiento : 'SE APAGA FORMADORA Y SE ABRE EL HORNO', inicio_intervencion : '2010-10-16 12:30:00.000', equipo : '414', fin_intervencion : '2010-10-16 13:00:00.000', accion_cierre : 'SE CAMBIAN ESCOBILLAS', descripcion_repuesto : 'AEROSOL CONTAC CLEANER LIMPIAD', cantidad : '20.000' }) RETURN l1
# 839 CREATE (l1:Solucion { id : '839', descripcion: 'SE APAGA FORMADORA Y SE ABRE E', mantenimiento : 'SE APAGA FORMADORA Y SE ABRE EL HORNO', inicio_intervencion : '2010-10-16 12:30:00.000', equipo : '414', fin_intervencion : '2010-10-16 13:00:00.000', accion_cierre : 'SE CAMBIAN ESCOBILLAS', descripcion_repuesto : 'CAPS P/N 458-001-0001', cantidad : '80.000' }) RETURN l1
# 840 CREATE (l1:Solucion { id : '840', descripcion: 'SE APAGA FORMADORA Y SE ABRE E', mantenimiento : 'SE APAGA FORMADORA Y SE ABRE EL HORNO', inicio_intervencion : '2010-10-16 12:30:00.000', equipo : '414', fin_intervencion : '2010-10-16 13:00:00.000', accion_cierre : 'SE CAMBIAN ESCOBILLAS', descripcion_repuesto : 'SPRING FLEXIBLE COUPLING P/N 1', cantidad : '10.000' }) RETURN l1
# 841 CREATE (l1:Solucion { id : '841', descripcion: 'SE CAYO UNO DE LOS  BRAZOS DEL', mantenimiento : 'SE CAYO UNO DE LOS  BRAZOS DELANTEROS DE LA PLACHA SUPERIOR DEL MOLDE', inicio_intervencion : '2010-03-16 11:00:00.000', equipo : '414', fin_intervencion : '2010-03-16 13:00:00.000', accion_cierre : 'SE EXTRAE TORNILLO Y SE COLOCA ARANDELA PROVICIONAL.', descripcion_repuesto : 'FRANELA GRANDE CRUDA 100% ALGO', cantidad : '200.000' }) RETURN l1
# 842 CREATE (l1:Solucion { id : '842', descripcion: 'SE CAYO UNO DE LOS  BRAZOS DEL', mantenimiento : 'SE CAYO UNO DE LOS  BRAZOS DELANTEROS DE LA PLACHA SUPERIOR DEL MOLDE', inicio_intervencion : '2010-03-16 11:00:00.000', equipo : '414', fin_intervencion : '2010-03-16 13:00:00.000', accion_cierre : 'SE EXTRAE TORNILLO Y SE COLOCA ARANDELA PROVICIONAL.', descripcion_repuesto : 'GRASA MOBILUX EP2 EN CUÑETE PO', cantidad : '10.000' }) RETURN l1
# 843 CREATE (l1:Solucion { id : '843', descripcion: 'SE DAÑO RODAMIENTO BRAZO SUPER', mantenimiento : 'SE DAÑO RODAMIENTO BRAZO SUPERIOR LADO DERECHO.', inicio_intervencion : '2010-03-15 20:00:00.000', equipo : '414', fin_intervencion : '2010-03-15 22:30:00.000', accion_cierre : 'SE BAJA BRAZO, SE ARREGLA Y SE LE MONTA RODAMIENTO NUEVO.', descripcion_repuesto : 'AEROSOL CONTAC CLEANER LIMPIAD', cantidad : '40.000' }) RETURN l1
# 844 CREATE (l1:Solucion { id : '844', descripcion: 'SE DAÑO RODAMIENTO BRAZO SUPER', mantenimiento : 'SE DAÑO RODAMIENTO BRAZO SUPERIOR LADO DERECHO.', inicio_intervencion : '2010-03-15 20:00:00.000', equipo : '414', fin_intervencion : '2010-03-15 22:30:00.000', accion_cierre : 'SE BAJA BRAZO, SE ARREGLA Y SE LE MONTA RODAMIENTO NUEVO.', descripcion_repuesto : 'RUEDA 4-PB-45-A- 130 KG- GIRAT', cantidad : '10.000' }) RETURN l1
# 845 CREATE (l1:Solucion { id : '845', descripcion: 'SE DAÑO RODAMIENTO BRAZO SUPER', mantenimiento : 'SE DAÑO RODAMIENTO BRAZO SUPERIOR LADO DERECHO.', inicio_intervencion : '2010-03-15 20:00:00.000', equipo : '414', fin_intervencion : '2010-03-15 22:30:00.000', accion_cierre : 'SE BAJA BRAZO, SE ARREGLA Y SE LE MONTA RODAMIENTO NUEVO.', descripcion_repuesto : 'FELPA  SEMIDURA PARA SELLADORA', cantidad : '20.000' }) RETURN l1
# ...
# 5713 CREATE (l1:Solucion { id : '5713', descripcion: 'Revisar hornos de las termofor', mantenimiento : 'Revisar hornos de las termoformadoras 14 y 15 porque no coren solos ', inicio_intervencion : '2022-12-07 10:01:00.000', equipo : '641', fin_intervencion : '2022-12-07 10:31:00.000', accion_cierre : 'se realiza verificacion de cilindros de desplazamientos', descripcion_repuesto : 'CABLE ENCAUCHETADO FLEXIBLE 3', cantidad : '100.000' }) RETURN l1
# 5714 CREATE (l1:Solucion { id : '5714', descripcion: 'Riel derecho caliente', mantenimiento : 'Riel derecho caliente', inicio_intervencion : '2021-08-11 12:45:00.000', equipo : '641', fin_intervencion : '2021-08-11 13:45:00.000', accion_cierre : 'SE VERIFICA SE AJUSTA RIEL SE AJUSTA REFRIGERACION SE ENTREGA  FUNCIONANDO', descripcion_repuesto : 'CARCAZA EN POLIPROPILENO DE 10', cantidad : '10.000' }) RETURN l1
# 5715 CREATE (l1:Solucion { id : '5715', descripcion: 'Riel derecho caliente', mantenimiento : 'Riel derecho caliente', inicio_intervencion : '2021-08-11 12:45:00.000', equipo : '641', fin_intervencion : '2021-08-11 13:45:00.000', accion_cierre : 'SE VERIFICA SE AJUSTA RIEL SE AJUSTA REFRIGERACION SE ENTREGA  FUNCIONANDO', descripcion_repuesto : 'SWC-25-1005 CARTUCHO MICROFILT', cantidad : '20.000' }) RETURN l1
# 5716 CREATE (l1:Solucion { id : '5716', descripcion: 'Riel derecho caliente', mantenimiento : 'Riel derecho caliente', inicio_intervencion : '2021-08-11 12:45:00.000', equipo : '641', fin_intervencion : '2021-08-11 13:45:00.000', accion_cierre : 'SE VERIFICA SE AJUSTA RIEL SE AJUSTA REFRIGERACION SE ENTREGA  FUNCIONANDO', descripcion_repuesto : 'MANOMETRO - 0 / 160 PSI-CARATU', cantidad : '10.000' }) RETURN l1
# 5717 CREATE (l1:Solucion { id : '5717', descripcion: 'Riel taponado', mantenimiento : 'Riel taponado ', inicio_intervencion : '2021-03-25 20:29:20.427', equipo : '641', fin_intervencion : '2021-03-25 20:31:30.000', accion_cierre : 'Se realizan purgas al sist la con aire comprimido y agua', descripcion_repuesto : 'ACEITE MOBIL VACTRA OIL 2', cantidad : '100.000' }) RETURN l1
# 5718 CREATE (l1:Solucion { id : '5718', descripcion: 'SE CALIENTA MOLDE INFERIOR.', mantenimiento : 'SE CALIENTA MOLDE INFERIOR.', inicio_intervencion : '2012-03-18 02:15:00.000', equipo : '641', fin_intervencion : '2012-03-18 02:45:00.000', accion_cierre : 'SE AJUSTA BOBINA Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'TUBING PARA LUBRICACION (ALTA ', cantidad : '20.000' }) RETURN l1
# 5719 CREATE (l1:Solucion { id : '5719', descripcion: 'SE CALIENTA MOLDE INFERIOR.', mantenimiento : 'SE CALIENTA MOLDE INFERIOR.', inicio_intervencion : '2012-03-18 02:15:00.000', equipo : '641', fin_intervencion : '2012-03-18 02:45:00.000', accion_cierre : 'SE AJUSTA BOBINA Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'MANGUERA DE CAUCHO DIA 1/2`` P', cantidad : '20.000' }) RETURN l1
# 5720 CREATE (l1:Solucion { id : '5720', descripcion: 'SE CALIENTA MOLDE INFERIOR.', mantenimiento : 'SE CALIENTA MOLDE INFERIOR.', inicio_intervencion : '2012-03-18 02:15:00.000', equipo : '641', fin_intervencion : '2012-03-18 02:45:00.000', accion_cierre : 'SE AJUSTA BOBINA Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'BROCA PARA METAL PUNTA TUNGSTE', cantidad : '10.000' }) RETURN l1
# 5721 CREATE (l1:Solucion { id : '5721', descripcion: 'SE CALIENTA MOLDE INFERIOR.', mantenimiento : 'SE CALIENTA MOLDE INFERIOR.', inicio_intervencion : '2012-03-18 02:15:00.000', equipo : '641', fin_intervencion : '2012-03-18 02:45:00.000', accion_cierre : 'SE AJUSTA BOBINA Y SE NORMALIZA FUNCIONAMIENTO.', descripcion_repuesto : 'HEXAGONO EN ALUMINIO REF: T 11', cantidad : '10.000' }) RETURN l1
# 5722 CREATE (l1:Solucion { id : '5722', descripcion: 'SE ESTALLO UNA MANGUERA DEL AG', mantenimiento : 'SE ESTALLO UNA MANGUERA DEL AGUA', inicio_intervencion : '2011-12-20 22:30:00.000', equipo : '641', fin_intervencion : '2011-12-20 23:30:00.000', accion_cierre : 'SE CAMBIO MANGUERA.', descripcion_repuesto : 'FRANELA GRANDE CRUDA 100% ALGO', cantidad : '200.000' }) RETURN l1
# 5723 CREATE (l1:Solucion { id : '5723', descripcion: 'SE ESTALLO UNA MANGUERA DEL AG', mantenimiento : 'SE ESTALLO UNA MANGUERA DEL AGUA', inicio_intervencion : '2011-12-20 22:30:00.000', equipo : '641', fin_intervencion : '2011-12-20 23:30:00.000', accion_cierre : 'SE CAMBIO MANGUERA.', descripcion_repuesto : 'CORREA DENTADA 450 H 100', cantidad : '20.000' }) RETURN l1
# 5724 CREATE (l1:Solucion { id : '5724', descripcion: 'Se apaga bomba de vacio', mantenimiento : 'Se apaga bomba de vacio', inicio_intervencion : '2022-09-02 12:42:46.817', equipo : '641', fin_intervencion : '2022-09-02 12:43:44.000', accion_cierre : 'Se desmonta bomba Y SE CAMBIARON LOS FUSIBLES DAÑADOS', descripcion_repuesto : 'SELLO MECANICO 1" MONORESORTE ', cantidad : '10.000' }) RETURN l1
# 5725 CREATE (l1:Solucion { id : '5725', descripcion: 'Se apaga formadora', mantenimiento : 'Se apaga formadora', inicio_intervencion : '2022-04-22 18:45:00.000', equipo : '641', fin_intervencion : '2022-04-22 19:40:00.000', accion_cierre : 'Se revisa formadora se apaga al mover la puerta lateral derecha, se ajustan tornillos, se prueba nuevamente y ya no se apaga mientras esta en prueba formando en vacío.', descripcion_repuesto : 'ACEITE MOBIL VACTRA OIL 2', cantidad : '50.000' }) RETURN l1
# 5726 CREATE (l1:Solucion { id : '5726', descripcion: 'Se apaga formadora', mantenimiento : 'Se para la formadora micro puerta derecha de la formadora suelto', inicio_intervencion : '2022-04-22 18:45:00.000', equipo : '641', fin_intervencion : '2022-04-22 19:40:00.000', accion_cierre : 'Se ajustan todos los micros de la formadora y se verifica que no se apague haciendo la operación de formado en vacío', descripcion_repuesto : 'ABRAZADERA TIPO INDUSTRIAL, 31', cantidad : '10.000' }) RETURN l1
# 5727 CREATE (l1:Solucion { id : '5727', descripcion: 'Se apaga formadora', mantenimiento : 'Se para la formadora micro puerta derecha de la formadora suelto', inicio_intervencion : '2022-04-22 18:45:00.000', equipo : '641', fin_intervencion : '2022-04-22 19:40:00.000', accion_cierre : 'Se ajustan todos los micros de la formadora y se verifica que no se apague haciendo la operación de formado en vacío', descripcion_repuesto : 'TOOTHED BELT T10 B 32 L 560 P/', cantidad : '10.000' }) RETURN l1
# 5728 CREATE (l1:Solucion { id : '5728', descripcion: 'Se apaga formadora', mantenimiento : 'Se para la formadora micro puerta derecha de la formadora suelto', inicio_intervencion : '2022-04-22 18:45:00.000', equipo : '641', fin_intervencion : '2022-04-22 19:40:00.000', accion_cierre : 'Se ajustan todos los micros de la formadora y se verifica que no se apague haciendo la operación de formado en vacío', descripcion_repuesto : 'TOOTHED BELT T10 B 32 L 560 P/', cantidad : '20.000' }) RETURN l1
# 5729 CREATE (l1:Solucion { id : '5729', descripcion: 'Se apaga formadora', mantenimiento : 'Se para la formadora micro puerta derecha de la formadora suelto', inicio_intervencion : '2022-04-22 18:45:00.000', equipo : '641', fin_intervencion : '2022-04-22 19:40:00.000', accion_cierre : 'Se ajustan todos los micros de la formadora y se verifica que no se apague haciendo la operación de formado en vacío', descripcion_repuesto : 'TOOTHED BELT T10 B 5 L 560 P/N', cantidad : '20.000' }) RETURN l1
# 5730 CREATE (l1:Solucion { id : '5730', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'MANGUERA PLASTICA SPIRAFLEX SL', cantidad : '40.000' }) RETURN l1
# 5731 CREATE (l1:Solucion { id : '5731', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'TORNILLO BRISTOL CON CABEZA - ', cantidad : '60.000' }) RETURN l1
# 5732 CREATE (l1:Solucion { id : '5732', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'BROCA PARA METAL PUNTA TUNGSTE', cantidad : '10.000' }) RETURN l1
# 5733 CREATE (l1:Solucion { id : '5733', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'RODAMIENTO DE BOLAS RIGIDO REF', cantidad : '20.000' }) RETURN l1
# 5734 CREATE (l1:Solucion { id : '5734', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'UNION MEDIO PASO PARA CADENA S', cantidad : '20.000' }) RETURN l1
# 5735 CREATE (l1:Solucion { id : '5735', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'SIMODRIVE 611INFEED REGENERATI', cantidad : '10.000' }) RETURN l1
# 5736 CREATE (l1:Solucion { id : '5736', descripcion: 'Se apaga formadora y presenta ', mantenimiento : 'Se apaga formadora y presenta falla en el dryve de la cadena', inicio_intervencion : '2014-07-11 14:00:00.000', equipo : '641', fin_intervencion : '2014-07-11 15:00:00.000', accion_cierre : 'SE CAMBIO FUENTE DEL BUS DC Y DRIVE DEL MOTOR DE LA CADENA', descripcion_repuesto : 'SPLINE SHAFT  TP-33373-25', cantidad : '20.000' }) RETURN l1
# 5737 CREATE (l1:Solucion { id : '5737', descripcion: 'Se apagan molde yhorno', mantenimiento : 'Se apagan molde yhorno', inicio_intervencion : '2021-06-03 19:24:42.650', equipo : '641', fin_intervencion : '2021-06-03 19:52:52.000', accion_cierre : 'Se verifica sistema se encuentra bomba mokón molde superior frenada, se baja se realiza cambio de motor, se fabrica empaque, se lleva al área pero a la hora de realizar montaje motor es muy largo y no dentro, se baja nuevamente se realiza cambio de motor, consumó 2'3Amp. Entrega 19:50', descripcion_repuesto : 'UNION PARA MANGUERA DE 3/8', cantidad : '10.000' }) RETURN l1
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# <ipython-input-256-c1e1c97e6983> in <cell line: 4>()
#       5   with driver.session() as session:
#       6     print(solucion[0], add_soluciones(solucion[0], solucion[1]['descripcion_problema_produccion'], solucion[1]['descripcion_problema_mantenimiento'], solucion[1]['inicio_intervencion'], solucion[1]['equipo'], solucion[1]['fin_intervencion'], solucion[1]['accion_cierre'], solucion[1]['repuesto_utilizado'], solucion[1]['descripcion_repuesto'], solucion[1]['cantidad']))
# ----> 7     info = session.run(add_soluciones(solucion[0], solucion[1]['descripcion_problema_produccion'], solucion[1]['descripcion_problema_mantenimiento'], solucion[1]['inicio_intervencion'], solucion[1]['equipo'], solucion[1]['fin_intervencion'], solucion[1]['accion_cierre'], solucion[1]['repuesto_utilizado'], solucion[1]['descripcion_repuesto'], solucion[1]['cantidad']))
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/work/session.py in run(self, query, parameters, **kwargs)
#     287         bookmarks = self._get_bookmarks()
#     288         parameters = dict(parameters or {}, **kwargs)
# --> 289         self._auto_result._run(
#     290             query, parameters, self._config.database,
#     291             self._config.impersonated_user, self._config.default_access_mode,
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/work/result.py in _run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_categories)
#     168         self._pull()
#     169         self._connection.send_all()
# --> 170         self._attach()
#     171
#     172     def _pull(self):
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/work/result.py in _attach(self)
#     276         if self._exhausted is False:
#     277             while self._attached is False:
# --> 278                 self._connection.fetch_message()
#     279
#     280     def _buffer(self, n=None):
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_common.py in inner(*args, **kwargs)
#     178             def inner(*args, **kwargs):
#     179                 try:
# --> 180                     func(*args, **kwargs)
#     181                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     182                     assert not asyncio.iscoroutinefunction(self.__on_error)
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     714             hydration_hooks=self.responses[0].hydration_hooks
#     715         )
# --> 716         res = self._process_message(tag, fields)
#     717         self.idle_since = perf_counter()
#     718         return res
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_bolt5.py in _process_message(self, tag, fields)
#     334             self._server_state_manager.state = ServerStates.FAILED
#     335             try:
# --> 336                 response.on_failure(summary_metadata or {})
#     337             except (ServiceUnavailable, DatabaseUnavailable):
#     338                 if self.pool:
#
# /usr/local/lib/python3.9/dist-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     245         handler = self.handlers.get("on_summary")
#     246         Util.callback(handler)
# --> 247         raise Neo4jError.hydrate(**metadata)
#     248
#     249     def on_ignored(self, metadata=None):
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '3Amp': expected
#   "!="
#   "%"
#   "*"
#   "+"
#   ","
#   "-"
#   "."
#   "/"
#   ":"
#   "<"
#   "<="
#   "<>"
#   "="
#   "=~"
#   ">"
#   ">="
#   "AND"
#   "CONTAINS"
#   "ENDS"
#   "IN"
#   "IS"
#   "OR"
#   "STARTS"
#   "XOR"
#   "["
#   "^"
#   "}" (line 1, column 511 (offset: 510))
# "CREATE (l1:Solucion { id : '5737', descripcion: 'Se apagan molde yhorno', mantenimiento : 'Se apagan molde yhorno', inicio_intervencion : '2021-06-03 19:24:42.650', equipo : '641', fin_intervencion : '2021-06-03 19:52:52.000', accion_cierre : 'Se verifica sistema se encuentra bomba mokón molde superior frenada, se baja se realiza cambio de motor, se fabrica empaque, se lleva al área pero a la hora de realizar montaje motor es muy largo y no dentro, se baja nuevamente se realiza cambio de motor, consumó 2'3Amp. Entrega 19:50', descripcion_repuesto : 'UNION PARA MANGUERA DE 3/8', cantidad : '10.000' }) RETURN l1"
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^}
